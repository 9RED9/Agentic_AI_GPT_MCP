# %% [markdown]
# # RAG Agent (검색 증강 생성 에이전트)
#
# **RAG (Retrieval-Augmented Generation)** 는 외부 지식 소스에서 정보를 검색하여 LLM의 응답을 향상시키는 기술입니다.
#
# RAG 에이전트는 검색 도구를 사용하여 관련 문서를 찾고, 이를 컨텍스트로 활용하여 답변을 생성합니다.
#
# **참고**: [LangChain 공식 문서 - RAG Agent](https://docs.langchain.com/oss/python/langchain/rag)
#
# ## RAG 워크플로우
#
# 1. **인덱싱 (Indexing)**: 문서를 로드, 분할, 임베딩하여 벡터 스토어에 저장
# 2. **검색 및 생성 (Retrieval & Generation)**: 사용자 질문에 대해 관련 문서를 검색하고 답변 생성
#
# ## RAG 패턴 이해
#
# RAG는 두 가지 주요 접근 방식이 있습니다:
#
# ### 1 에이전트 기반 RAG (Agentic RAG)
#
# 에이전트가 필요할 때만 검색 도구를 호출합니다.
# - 장점: 유연성, 필요할 때만 검색
# - 단점: 여러 번의 모델 호출로 인한 지연 시간
#
# ### 2 체인 기반 RAG (Chain-based RAG)
#
# 항상 검색을 먼저 실행하고 결과를 컨텍스트로 제공합니다.
# - 장점: 단일 모델 호출로 빠름
# - 단점: 항상 검색하므로 유연성 낮음

# %%
from dotenv import load_dotenv
import os

load_dotenv()

# LangSmith 추적 (선택적)
langsmith_api_key = os.getenv("LANGCHAIN_API_KEY", "")
if langsmith_api_key:
    os.environ["LANGCHAIN_TRACING_V2"] = "true"

# %%
from langchain.chat_models import init_chat_model
from langchain_openai import OpenAIEmbeddings
from langchain_core.vectorstores import InMemoryVectorStore

# 모델 및 임베딩 초기화
model = init_chat_model("gpt-5-nano", model_provider="openai")
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# 벡터 스토어 생성
vector_store = InMemoryVectorStore(embeddings)

# %% [markdown]
# ## 1. 인덱싱 단계
#
# 문서를 로드하고 벡터 스토어에 저장합니다.

# %% [markdown]
# ### 1.1 문서 로드 및 분할

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 웹 문서 로드
loader = WebBaseLoader("https://botpress.com/ko/blog/llm-agents")
docs = loader.load()

print(f"로드된 문서 수: {len(docs)}")
print(f"문서 길이: {len(docs[0].page_content)} 문자")

# 텍스트 분할
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    add_start_index=True
)

all_splits = text_splitter.split_documents(docs)
print(f"\n분할된 청크 수: {len(all_splits)}")
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# 로드된 문서 수: 1
# 문서 길이: 9530 문자
#
# 분할된 청크 수: 17

# %% [markdown]
# ### 1.2 벡터 스토어에 저장

# %%
# 문서를 벡터 스토어에 추가
document_ids = vector_store.add_documents(documents=all_splits)
print(f"저장된 문서 ID 수: {len(document_ids)}")
# Out:
# 저장된 문서 ID 수: 17

# %% [markdown]
# ### 2. 에이전트 기반 RAG (Agentic RAG)

# %% [markdown]
# ### 2.1 검색 도구 생성

# %%
from langchain.tools import tool

@tool(response_format="content_and_artifact")
def retrieve_context(query: str):
    """질문에 답하기 위해 관련 정보를 검색합니다.
    
    이 도구는 벡터 스토어에서 질문과 관련된 문서를 검색합니다.
    검색된 문서는 답변 생성에 사용됩니다.
    
    Args:
        query: 검색할 질문 또는 키워드
    """
    # 벡터 스토어에서 유사한 문서 검색
    retrieved_docs = vector_store.similarity_search(query, k=2)
    
    # 검색된 문서를 문자열로 직렬화
    serialized = "\n\n".join(
        f"출처: {doc.metadata.get('source', 'N/A')}\n내용: {doc.page_content}"
        for doc in retrieved_docs
    )
    
    # 문자열과 문서 객체를 함께 반환
    return serialized, retrieved_docs

# 도구 테스트
test_result = retrieve_context.invoke("LLM 에이전트의 구성 요소")
print(test_result[0][:300] + "...")
# Out:
# 출...

# %% [markdown]
# ### 2.2 RAG 에이전트 생성

# %%
from langchain.agents import create_agent

# 시스템 프롬프트 설정
system_prompt = (
    "당신은 블로그 게시글에서 관련 문맥(context)을 검색하는 도구에 접근할 수 있습니다. "
    "사용자의 질문에 답하기 위해 먼저 retrieve_context 도구를 사용하여 관련 정보를 검색한 후, "
    "검색된 정보를 바탕으로 정확하고 유용한 답변을 제공하세요."
)

# 에이전트 생성
agent = create_agent(
    model,
    tools=[retrieve_context],
    system_prompt=system_prompt
)

agent

# %% [markdown]
# ### 2.3 에이전트 실행

# %%
# 질문에 대한 답변 생성
query = "LLM 에이전트 프레임워크를 구성하는 핵심 구성 요소는 무엇인가요?"

print(f"질문: {query}\n")
print("=" * 80)

# 스트리밍 방식으로 실행
for event in agent.stream(
    {"messages": [{"role": "user", "content": query}]},
    stream_mode="values",
):
    event["messages"][-1].pretty_print()
# Out:
# 질문: LLM 에이전트 프레임워크를 구성하는 핵심 구성 요소는 무엇인가요?
#
# ================================================================================
# ================================ Human Message =================================
#
# LLM 에이전트 프레임워크를 구성하는 핵심 구성 요소는 무엇인가요?
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve_context (call_ogRDygrQnApyrL0ffIYvTxiv)
#  Call ID: call_ogRDygrQnApyrL0ffIYvTxiv
#   Args:
#     query: LLM 에이전트 프레임워크 핵심 구성 요소
# ================================= Tool Message =================================
# Name: retrieve_context
#
# 출처: https://botpress.com/ko/blog/llm-agents
# 내용: 최신 LLM으로 구동되는 맞춤형 자율 에이전트 구축
#
#
# 지금 시작하기
#
#
#
#
#
#
#
#
#
# LLM 에이전트는 어떻게 작동하나요?LLM 에이전트는 LLM의 강력함에 검색, 추론, 메모리, 도구 활용을 결합해 자율적으로 작업을 완수합니다. 각 구성 요소의 역할을 살펴보겠습니다.
#
# 검색
# 대부분의 에이전트는 검색 증강 생성(RAG)을 사용해 실시간 데이터에 접근합니다. 예를 들어, 법률 에이전트는 규제 변경 사항을, 이커머스 에이전트는 상품 재고를 확인할 수 있습니다.
#
#
#
# 추론
# LLM 에이전트 개발자는 고급 프롬프트 기법을 활용해 에이전트의 의사결정 방식을 안내할 수 있습니다.
#
#
#
# 메모리
# LLM 에이전트는 단기 메모리(최근 대화 이력), 장기 메모리(구조화된 정보 저장), 작업별 기억 기능을 갖추고 있어, 상황에 맞게 적응하고 개인화된 결정을 내릴 수 있습니다.
#
#
#
# 도구 사용
# 대화뿐 아니라, LLM 에이전트는 거의 모든 외부 시스템과 연동해 데이터를 가져오거나 작업을 수행할 수 있습니다. 예를 들어, 파이썬 코드를 실행해 오류를 디버깅하거나 CRM에서 사용자의 주문 이력을 확인할 수 있습니다.
#
# 출처: https://botpress.com/ko/blog/llm-agents
# 내용: ‍이러한 기능이 결합되어 LLM 에이전트는 복잡하고 다단계의 워크플로우도 완전히 자율적으로 처리할 수 있습니다.예를 들어:B2B 영업 에이전트는 CRM에서 잠재 고객 데이터를 검색하고, 거래 진행 상황을 분석하며, 과거 상호작용을 기억해 맞춤형 후속 조치를 취하고, 이메일과 캘린더 API를 활용해 발송 및 일정을 잡습니다.IT 에이전트는 시스템 로그를 검색해 오류를 진단하고, 문제 해결 단계를 분석하며, 이전 사용자 이슈에서 효과적이었던 방법을 기억하고, 스크립트를 실행해 서비스를 재시작하거나 티켓을 생성합니다.LLM 에이전트를 정의하는 4가지 특징은 무엇인가요?LLM 에이전트의 핵심 특징 네 가지는 다음과 같습니다.1. 언어 모델언어 모델은 LLM 에이전트의 ‘두뇌’로 여겨집니다. 모델의 품질과 규모가 LLM 에이전트의 성능에 직접적인 영향을 미칩니다.방대한 텍스트 데이터로 학습된 정교한 알고리즘으로, 맥락을 이해하고 패턴을 인식하며 일관성 있고 상황에 맞는 답변을 생성할 수 있습니다.언어 패턴을 식별하고 학습방대한 학습 데이터 덕분에 맥락 인식 능력 확보다양한 분야에 적응하고 폭넓은 주제 처리 가능언어 모델은 답변의 깊이, 정확성, 관련성을 결정하며, 에이전트의 언어 능력의 기반이 됩니다.2. 메모리메모리는 과거 상호작용에서 얻은 정보(사실, 사용자 선호, 세션 간 주제 등)를 기억하는 능력을 의미합니다.이 기능은 에이전트의 맥락 이해도를 높여 대화를 더 자연스럽고 연속적으로 만듭니다.일부 환경에서는 메모리를 통해 장기간 정보를 보존할 수 있습니다. 이를 통해 반복적인 사용자 행동이나 선호도를 ‘학습’할 수 있지만, 개인정보 보호와 관련성 유지를 위해 종종 규제됩니다.3. 도구 활용도구 활용은 LLM 에이전트를 단순 대화에서 실제 행동으로 확장시킵니다.LLM 에이전트는 외부 애플리케이션, 데이터베이스, API와 연동해 특정 기능을 수행할 수 있습니다.즉, 실시간 정보를 가져오거나 외부 작업을 실행하거나 특화된 데이터베이스에 접근할 수 있어, 실시간 정보
# ================================== Ai Message ==================================
#
# LLM 에이전트 프레임워크의 핵심 구성 요소는 일반적으로 다음 네 가지로 요약됩니다.
#
# - 검색( Retrieval, RAG )
#   - 실시간 데이터나 외부 정보에 접근하기 위한 검색/정보 획득 모듈.
#   - 예: 최신 규제 변경 보기, 재고 확인, 실시간 데이터 조회 등.
# - 추론/의사결정( Reasoning / Planning )
#   - 목표 달성을 위한 의사결정 로직과 다단계 계획 수립.
#   - 프롬프트 엔지니어링이나 정책/루프를 통해 에이전트의 행동 방식을 지휘합니다.
# - 메모리( Memory )
#   - 대화 맥락을 위한 단기 메모리와 장기 메모리(구조화된 정보 저장), 작업별 기억 등.
#   - 맥락 유지, 개인화된 응답 및 지속 가능한 대화 흐름에 기여합니다. 개인정보 보호 고려가 필요할 수 있습니다.
# - 도구 활용( Tooling / Action )
#   - 외부 시스템과의 연동으로 실제 작업을 수행하는 모듈.
#   - API 호출, 데이터베이스 접근, 코드 실행, CRM 조회, 이메일/캘린더 API 사용 등 다양한 액션을 수행합니다.
#
# 추가로, 이 네 가지 기능이 합쳐져 에이전트가 다단계의 복잡한 워크플로우를 자율적으로 처리할 수 있습니다. 예시로 B2B 영업 에이전트는 CRM 데이터를 조회하고, 거래를 분석하며, 과거 상호작용을 기억해 맞춤형 후속 조치를 취하고, 이메일이나 일정 관리 API로 자동화합니다.
#
# 요약하면, 현행 LLM 에이전트의 기본 프레임워크는 정보 획득(검색) → 판단과 계획(추론) → 맥락 저장/참조(메모리) → 실행(도구 활용) 흐름으로 작동합니다. 필요에 따라 각 구성 요소의 구현 방식과 명칭은 프레임워크에 따라 다를 수 있습니다.

# %% [markdown]
# ### 2.4 여러 질문 테스트

# %%
queries = [
    "에이전트의 주요 특징은 무엇인가요?",
    "프롬프트 엔지니어링이 중요한 이유는 무엇인가요?"
]

for query in queries:
    print(f"\n{'='*80}")
    print(f"질문: {query}")
    print("="*80)
    
    result = agent.invoke({
        "messages": [{"role": "user", "content": query}]
    })
    
    print("\n답변:")
    result["messages"][-1].pretty_print()
# Out:
# ================================================================================
# 질문: 에이전트의 주요 특징은 무엇인가요?
# ================================================================================
#
# 답변:
# ================================== Ai Message ==================================
#
# 에이전트의 주요 특징은 다음과 같습니다.
#
# - 자율성(Autonomy): LLM을 기반으로 스스로 의사결정하고 작업을 수행합니다.
# - 검색 능력(RAG): 실시간 데이터에 접근하기 위해 검색 증강 생성(RAG)을 사용합니다. 예를 들어 규제 변경이나 재고 상태를 확인하는 식으로 맥락을 보강합니다.
# - 추론 능력: 고급 프롬프트 기법을 활용해 의사결정 방식과 행동 계획을 설계하고 실행합니다.
# - 메모리 관리:
#   - 단기 메모리: 최근 대화 이력으로 현재 상황을 파악합니다.
#   - 장기 메모리: 구조화된 정보 저장으로 맥락을 축적하고 개인화된 결정을 내립니다.
#   - 작업별 기억: 특정 작업의 정보를 지속적으로 활용합니다.
# - 도구 활용/외부 시스템 연동: 다양한 외부 시스템과 연동해 데이터를 가져오고 작업을 수행합니다. 예를 들어 파이썬 코드 실행으로 디버깅하거나 CRM의 주문 이력을 확인하는 등의 활용이 가능합니다.
#
# 요약하면, 자동화된 의사결정과 실행을 위해 검색, 추론, 맥락(메모리) 관리, 그리고 외부 도구 연동의 네 가지 핵심 요소가 결합된 형태입니다.
#
# ================================================================================
# 질문: 프롬프트 엔지니어링이 중요한 이유는 무엇인가요?
# ================================================================================
#
# 답변:
# ================================== Ai Message ==================================
#
# 프롬프트 엔지니어링은 LLM 기반 시스템의 성능과 비용, 활용 가능성을 좌우하는 핵심 기술입니다. 아래처럼 왜 중요한지 요약해 드립니다.
#
# 주요 이유
#
# - 비용과 유지보수의 균형: 파인튜닝은 비용이 크고 유지 관리가 필요합니다. 반면 프롬프트 엔지니어링은 모델 파라미터를 바꾸지 않고도 원하는 동작을 유도할 수 있어 초기 비용이 낮고 빠르게 수정·실험이 가능합니다. 파인튜닝은 정적 지식에 강한 챗봇 등에 유리하지만, 실시간 정보에는 한계가 있습니다.
#
# - 성능 향상의 쉬운 실현: N-샷 러닝(제로샷, 원샷, N샷) 방식은 한 번의 API 호출에 예시를 주는 것만으로도 답변 품질을 크게 높일 수 있습니다. 예시를 더 많이 주면 성능이 더 좋아지지만, 컨텍스트 크기와 요금은 증가합니다. 파인튜닝 없이도 성능 개선이 가능하다는 점이 큰 장점입니다.
#
# - 추론 품질과 신뢰성 향상: 체인 오브 트 thought(Chain-of-Thought) 같은 프롬프트 기법은 추론이 중요한 작업에서 답변의 품질과 신뢰성을 크게 높일 수 있습니다. 다만 이로 인해 출력 길이, 토큰 사용량, 속도가 느려지는 단점이 있습니다. 필요에 따라 체이닝(프롬프트 체이닝)으로 여러 단계로 문제를 분해해 처리하는 전략도 있습니다.
#
# - 실전 활용의 유연성: 프롬프트를 통해 목표를 명확히 설정하고, 에이전트의 대화 흐름이나 작업 흐름을 설계할 수 있습니다. 특히 LLM 에이전트 구축에서 “목표 설정 → 작업 분해 → 실행” 같은 흐름을 프롬프트로 안내하는 것이 핵심적입니다. 이를 통해 지식 베이스를 활용하거나 휴먼 핸드오프를 포함한 복잡한 대화를 관리할 수 있습니다.
#
# - 적합한 도구와 상황에 맞춘 선택: 파인튜닝이 필요한 경우도 있지만, 대부분의 경우 프롬프트 엔지니어링으로 충분히 강력한 성능을 얻을 수 있습니다. 특히 정적 지식이 아닌 동적 정보가 필요한 상황에서 검색/회수 기반의 프롬프트 설계가 큰 효과를 냅니다.
#
# 단점과 주의점
#
# - 비용/속도/출력 길이 증가: 체인오브트thought나 체이닝 같은 고급 프롬프트는 답변의 품질을 높이지만, 출력이 길어지고 토큰 수가 늘어나며 처리 속도가 느려질 수 있습니다.
#
# - 지나친 의존의 위험: 너무 많이 예시를 주면 컨텍스트 창이 빨리 차고 비용이 증가합니다. 상황에 따라 필요한 최소한의 예시를 찾는 것이 중요합니다.
#
# 실전 팁(간단 가이드)
#
# - 목표를 분명히 하기: 어떤 업무를 달성할지, 누구를 대상으로 하는지, 출력 형식은 무엇인지 명확히 설정합니다.
#
# - 예시의 적절한 사용: 제로샷, 원샷, N샷 중 상황에 맞는 방식을 선택하고, 필요하면 1~3개 정도의 예시로 시작해 보며 점진적으로 조정합니다.
#
# - 출력 형식 관리: JSON이나 YAML 같은 구조화된 형식으로 요구하면 후처리가 쉬워 집니다.
#
# - 필요 시 체이닝: 복잡한 작업은 단계를 나눠 순차적으로 프롬프트를 실행하도록 설계하면 성능이 더 안정적일 수 있습니다.
#
# - 실시간 정보 연결: 정적 지식이 아니라 실시간 정보가 필요하면 프롬프트에 검색/조회 결과를 포함시키는 방식으로 회수-생성 파이프라인을 구성합니다.
#
# 요약
#
# 프롬프트 엔지니어링은 비용 효율적으로 성능을 끌어올리고, 실시간 정보 활용과 복잡한 작업의 추론 품질을 개선하는 데 핵심적인 도구입니다. 다만 과도한 예시 사용이나 고급 체이닝은 비용과 속도에 영향을 주므로 상황에 맞게 균형을 맞추는 것이 중요합니다.

# %% [markdown]
# ### 3. 체인 기반 RAG (Chain-based RAG)

# %%
# 체인 기반 RAG 예제
from langchain_core.messages import HumanMessage

def chain_based_rag(query: str):
    """체인 기반 RAG: 항상 검색 후 답변 생성"""
    # 1. 검색
    retrieved_docs = vector_store.similarity_search(query, k=2)
    context = "\n\n".join(doc.page_content for doc in retrieved_docs)
    
    # 2. 컨텍스트와 함께 답변 생성
    messages = [
        HumanMessage(content=f"""다음 컨텍스트를 참고하여 질문에 답변하세요:

컨텍스트:
{context}

질문: {query}

답변:""")
    ]
    
    response = model.invoke(messages)
    return response.content

# 체인 기반 RAG 테스트
query = "에이전트의 주요 특징은?"
print(f"질문: {query}\n")
answer = chain_based_rag(query)
print(f"답변: {answer}")
# Out:
# 질문: 에이전트의 주요 특징은?
#
# 답변: 에이전트의 주요 특징은 다음 네 가지입니다.
#
# - 검색 기능: 실시간 데이터에 접근하기 위해 검색 증강(RAG)을 사용합니다(예: 규제 변경 확인, 재고 조회 등).
# - 추론 능력: 고급 프롬프트 기법으로 의사결정 과정을 가이드하고 합리적인 판단을 내립니다.
# - 메모리: 단기 대화 이력과 장기 메모리(구조화된 정보)로 맥락을 유지하고 개인화된 반응을 제공합니다.
# - 도구 활용: 외부 시스템(API, 데이터베이스, 코딩 실행 등)과 연동해 데이터를 조회하고 작업을 실제로 수행합니다.
#
# 이 네 가지를 결합해 자율적으로 다단계 워크플로우를 처리합니다.

# %% [markdown]
# ## 4. 실전 예제: PDF 문서 기반 RAG

# %%
from langchain_community.document_loaders import PyPDFLoader

# PDF 문서 로드 (이미 110_Semantic_Search.py에서 인덱싱했다고 가정)
# 실제로는 별도의 인덱싱 프로세스로 실행

# PDF 기반 검색 도구
@tool(response_format="content_and_artifact")
def retrieve_pdf_context(query: str):
    """PDF 문서에서 관련 정보를 검색합니다."""
    # 실제로는 별도로 인덱싱된 PDF 벡터 스토어 사용
    # 여기서는 예제로 기존 벡터 스토어 사용
    retrieved_docs = vector_store.similarity_search(query, k=3)
    
    serialized = "\n\n".join(
        f"페이지: {doc.metadata.get('page', 'N/A')}\n내용: {doc.page_content}"
        for doc in retrieved_docs
    )
    
    return serialized, retrieved_docs

# PDF RAG 에이전트
pdf_agent = create_agent(
    model,
    tools=[retrieve_pdf_context],
    system_prompt="당신은 PDF 문서를 검색하여 질문에 답변하는 AI 어시스턴트입니다."
)

pdf_agent

# %% [markdown]
# ## 주요 포인트 정리
#
# 1. **인덱싱**: 문서 로드 → 분할 → 임베딩 → 벡터 스토어 저장
# 2. **검색 도구**: 벡터 스토어를 래핑한 도구 생성
# 3. **에이전트 통합**: 검색 도구를 에이전트에 추가
# 4. **에이전트 기반 vs 체인 기반**: 필요에 따라 선택
#
# **다음 단계**:
# - [230_Custom_RAG_LangGraph.py](230_Custom_RAG_LangGraph.py)에서 LangGraph로 더 세밀한 제어 구현
# - [streamlit-llm_LangChain/120_RAG_Chatbot.py](streamlit-llm_LangChain/120_RAG_Chatbot.py)에서 웹 UI 구현
