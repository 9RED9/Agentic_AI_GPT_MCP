# %% [markdown]
# # Handoffs Pattern (에이전트 간 핸드오프 패턴)
#
# **핸드오프 패턴(Handoffs Pattern)** 은 단일 에이전트가 여러 상태(state)를 거치며 작업을 수행하는 패턴입니다.
# 각 상태마다 다른 프롬프트와 도구를 사용하여, 복잡한 워크플로우를 단일 에이전트로 구현할 수 있습니다.
#
# 이 튜토리얼에서는 고객 지원(Customer Support) 시나리오를 구현합니다:
# - 보증 상태 확인 → 이슈 분류 → 해결책 제공
#
# **참고**: [LangChain 공식 문서 - Handoffs Customer Support](https://docs.langchain.com/oss/python/langchain/multi-agent/handoffs-customer-support)

# %%
from dotenv import load_dotenv
import os

load_dotenv()

# LangSmith 추적 (선택적)
langsmith_api_key = os.getenv("LANGCHAIN_API_KEY", "")
if langsmith_api_key:
    os.environ["LANGCHAIN_TRACING_V2"] = "true"
    os.environ["LANGCHAIN_API_KEY"] = langsmith_api_key
    os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT", "LangChain_V1")

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("gpt-5-mini", model_provider="openai")

# %% [markdown]
# ## 1. 상태 스키마 정의
#
# 워크플로우의 상태를 정의합니다. 각 단계와 수집된 정보를 저장합니다.
# ```
# Agent Workflow
#    ↓
# State(State 객체)
#    ↓
# 각 Step 노드가 State 읽고 수정
#    ↓
# 그래프가 다음 Step 결정
# ```

# %%
from langchain.agents import AgentState
from typing_extensions import NotRequired
from typing import Literal

# 가능한 워크플로우 단계
SupportStep = Literal["warranty_collector", "issue_classifier", "resolution_specialist"]  #상태 값 제한 패턴

# 보증 상태
WarrantyStatus = Literal["in_warranty", "out_of_warranty"]

# 이슈 유형
IssueType = Literal["hardware", "software"]

class SupportState(AgentState):
    """고객 지원 워크플로우 상태"""
    current_step: NotRequired[SupportStep]  # 워크플로우 현재 단계
    warranty_status: NotRequired[WarrantyStatus]  # 보증 상태
    issue_type: NotRequired[IssueType]  # 이슈 유형

# %% [markdown]
# ## 2. 상태 관리 도구 정의
#
# 각 단계에서 상태를 업데이트하는 도구를 정의합니다.

# %%
from langchain.tools import tool, ToolRuntime
from langchain.messages import ToolMessage
from langgraph.types import Command


@tool
def record_warranty_status(
    status: Literal["in_warranty", "out_of_warranty"],
    runtime: ToolRuntime[None, SupportState],
) -> Command:
    """
    고객의 보증 상태를 기록하고 다음 단계(이슈 분류 단계)로 전환하는 Tool
    
    역할:
        1. 고객의 제품 보증 상태 저장
        2. 상태(State)에 메시지 기록
        3. 워크플로우를 다음 단계(issue_classifier)로 이동
    
    Args:
        status:
            고객 제품 보증 상태
            - "in_warranty" : 보증 기간 내
            - "out_of_warranty" : 보증 기간 외
            
        runtime:
            Tool 실행 환경 정보
            - tool_call_id : Tool 호출 추적 ID
            - 현재 Agent 실행 Context 접근 가능
            
    Returns:
        Command 객체
        → LangGraph State 업데이트 및 다음 단계 제어
    """
    
    return Command(
        update={
            # Tool 실행 결과를 메시지 히스토리에 추가
            "messages": [
                ToolMessage(
                    content=f"Warranty status recorded as: {status}",
                    # Tool 호출과 메시지를 연결하기 위한 ID
                    tool_call_id=runtime.tool_call_id,
                )
            ],
            
            # 고객 보증 상태를 State 에 저장
            "warranty_status": status,
            # 다음 워크플로우 단계 지정
            "current_step": "issue_classifier",
        }
    )


@tool
def record_issue_type(
    issue_type: Literal["hardware", "software"],
    runtime: ToolRuntime[None, SupportState],  #입력 컨텍스트는 없고(None) Agent State 타입은 SupportState를 사용
) -> Command:
    """
    고객 문제 유형을 기록하고 해결 단계로 전환하는 Tool
    
    역할:
        1. 문제 유형 저장
        2. 상태(State)에 메시지 기록
        3. 워크플로우를 해결 전문가 단계로 이동
    
    Args:
        issue_type:
            문제 유형
            - "hardware" : 하드웨어 문제
            - "software" : 소프트웨어 문제
            
        runtime:
            Tool 실행 런타임 정보
            - tool_call_id 포함
            
    Returns:
        Command 객체
        → State 업데이트 + 다음 단계 이동
    """
    
    return Command(
        update={
            # Tool 실행 결과 메시지 기록
            "messages": [
                ToolMessage(
                    content=f"Issue type recorded as: {issue_type}",
                    tool_call_id=runtime.tool_call_id,
                )
            ],
            
            # 문제 유형 상태 저장
            "issue_type": issue_type,
            # 다음 단계 설정
            "current_step": "resolution_specialist",
        }
    )


@tool
def escalate_to_human(reason: str) -> str:
    """
    고객 문제를 사람이 직접 처리하도록 에스컬레이션하는 Tool
    
    실제 시스템에서는:
        - 지원 티켓 생성
        - 담당자 알림 전송
        - CRM 시스템 등록
        등의 동작이 수행될 수 있음
    
    Args:
        reason:
            사람이 처리해야 하는 이유
            
    Returns:
        에스컬레이션 결과 메시지
    """
    
    # 실제 서비스에서는 외부 시스템 연동 로직이 들어갈 위치
    return f"Escalating to human support. Reason: {reason}"


@tool
def provide_solution(solution: str) -> str:
    """
    고객 문제 해결 방안을 제공하는 Tool
    
    역할:
        - 고객에게 해결 방법 안내
        - 자동 응답 시스템에서 해결 메시지 생성
        
    Args:
        solution:
            고객에게 전달할 해결 방안
            
    Returns:
        해결 안내 메시지
    """
    
    return f"Solution provided: {solution}"

# %% [markdown]
# ## 3. 단계별 프롬프트 정의
#
# 각 단계마다 다른 시스템 프롬프트를 사용합니다.

# %%
# 보증 수집 단계 프롬프트
WARRANTY_COLLECTOR_PROMPT = """당신은 고객 지원 에이전트입니다.

현재 단계: 보증 확인

이 단계에서 해야 할 일:
1. 고객에게 친절하게 인사하세요
2. 기기가 보증 기간 내인지 물어보세요
3. record_warranty_status 도구를 사용하여 응답을 기록하고 다음 단계로 이동하세요

대화적이고 친근하게 대화하세요. 한 번에 여러 질문을 하지 마세요."""

# 이슈 분류 단계 프롬프트
ISSUE_CLASSIFIER_PROMPT = """당신은 고객 지원 에이전트입니다.

현재 단계: 이슈 분류
고객 정보: 보증 상태는 {warranty_status}입니다

이 단계에서 해야 할 일:
1. 고객에게 문제를 설명해달라고 요청하세요
2. 하드웨어 문제(물리적 손상, 부품 고장)인지 소프트웨어 문제(앱 충돌, 성능 저하)인지 판단하세요
3. record_issue_type 도구를 사용하여 분류를 기록하고 다음 단계로 이동하세요

불명확한 경우 분류하기 전에 명확히 질문하세요."""

# 해결책 제공 단계 프롬프트
RESOLUTION_SPECIALIST_PROMPT = """당신은 고객 지원 에이전트입니다.

현재 단계: 해결책 제공
고객 정보: 보증 상태는 {warranty_status}, 이슈 유형은 {issue_type}입니다

이 단계에서 해야 할 일:
1. 소프트웨어 문제인 경우: provide_solution을 사용하여 문제 해결 단계를 제공하세요
2. 하드웨어 문제인 경우:
   - 보증 기간 내: provide_solution을 사용하여 보증 수리 프로세스를 설명하세요
   - 보증 기간 만료: escalate_to_human을 사용하여 유료 수리 옵션을 위해 인간 지원으로 에스컬레이션하세요

구체적이고 도움이 되는 해결책을 제공하세요."""

# %% [markdown]
# ## 4. 단계별 설정(STEP_CONFIG) 및 wrap_model_call 미들웨어
#
# 최신 문서: 현재 상태(current_step)에 따라 프롬프트와 도구를 request.override로 주입합니다.

# %%
from langchain.agents.middleware import wrap_model_call, ModelRequest, ModelResponse
from typing import Callable

# ------------------------------------------------------------
# 단계별 Agent 설정 정보
# ------------------------------------------------------------
# 각 워크플로우 단계마다
#   1. 사용할 시스템 프롬프트
#   2. 허용할 Tool 목록
#   3. 해당 단계에 진입하기 위한 필수 상태(State)
# 를 정의하는 설정 테이블

STEP_CONFIG = {

    # -----------------------------
    # 보증 상태 수집 단계
    # -----------------------------
    "warranty_collector": {
        "prompt": WARRANTY_COLLECTOR_PROMPT,     # 해당 단계에서 사용할 시스템 프롬프트
        "tools": [record_warranty_status],       # 사용 가능한 Tool 목록
        "requires": [],                          # 진입 조건 (없음)
    },

    # -----------------------------
    # 이슈 분류 단계
    # -----------------------------
    "issue_classifier": {
        "prompt": ISSUE_CLASSIFIER_PROMPT,
        "tools": [record_issue_type],
        "requires": ["warranty_status"],         # warranty_status 가 먼저 기록되어야 진입 가능
    },

    # -----------------------------
    # 문제 해결 단계
    # -----------------------------
    "resolution_specialist": {
        "prompt": RESOLUTION_SPECIALIST_PROMPT,
        "tools": [provide_solution, escalate_to_human],
        "requires": ["warranty_status", "issue_type"],  # 두 상태 모두 필요
    },
}


# ------------------------------------------------------------
# Model Call Middleware 정의
# ------------------------------------------------------------
# wrap_model_call:
#   → LLM 호출 직전에 개입하여
#     - 시스템 프롬프트 변경
#     - Tool 목록 변경
#     - 요청 파라미터 수정
#   등을 수행할 수 있는 미들웨어 데코레이터

@wrap_model_call
def apply_step_config(
    request: ModelRequest,
    handler: Callable[[ModelRequest], ModelResponse],
) -> ModelResponse:
    """
    현재 Agent 상태에 따라
    - 시스템 프롬프트
    - 사용 가능한 Tool 목록
    을 동적으로 적용하는 Middleware

    실행 흐름:
        1. 현재 workflow 단계 확인
        2. 단계 진입 조건 검증
        3. 단계별 시스템 프롬프트 생성
        4. Tool 목록 설정
        5. 수정된 요청을 LLM에 전달
    """

    # ------------------------------------------------------------
    # 현재 단계 확인
    # ------------------------------------------------------------
    # state 에 current_step 값이 없으면 기본 단계는 warranty_collector
    current_step = request.state.get("current_step", "warranty_collector")

    # 해당 단계 설정 정보 조회
    stage_config = STEP_CONFIG[current_step]

    # ------------------------------------------------------------
    # 단계 진입 조건 검증
    # ------------------------------------------------------------
    # 특정 단계는 반드시 선행 상태가 있어야 진입 가능
    # 예:
    # issue_classifier → warranty_status 필요
    # resolution_specialist → warranty_status + issue_type 필요
    for key in stage_config["requires"]:
        if request.state.get(key) is None:
            raise ValueError(f"{key} must be set before reaching {current_step}")

    # ------------------------------------------------------------
    # 시스템 프롬프트 동적 생성
    # ------------------------------------------------------------
    # 현재 상태 값을 프롬프트에 삽입하여
    # LLM 이 현재 상황을 이해하도록 만듦

    format_kw = {
        # 보증 상태
        "warranty_status": request.state.get("warranty_status", "알 수 없음"),
        # 문제 유형
        "issue_type": request.state.get("issue_type", "알 수 없음"),
    }

    # 단계별 프롬프트 템플릿에 상태 값 삽입
    system_prompt = stage_config["prompt"].format(**format_kw)

    # ------------------------------------------------------------
    # ModelRequest 수정
    # ------------------------------------------------------------
    # override():
    #   기존 요청 객체를 복사하면서
    #   특정 필드만 변경하는 불변 객체 패턴

    request = request.override(
        system_prompt=system_prompt,   # 단계별 시스템 프롬프트 적용
        tools=stage_config["tools"],   # 단계별 Tool 허용 목록 적용
    )

    # 수정된 요청을 실제 LLM 호출 핸들러로 전달
    return handler(request)

# %% [markdown]
# ## 5. 에이전트 생성
#
# state_schema와 apply_step_config 미들웨어로 단계별 프롬프트·도구를 적용합니다.

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

# Agent 에서 사용할 모든 Tool 목록 정의
all_tools = [
    record_warranty_status,   # 보증 상태 기록 Tool
    record_issue_type,        # 문제 유형 기록 Tool
    provide_solution,         # 해결 방안 제공 Tool
    escalate_to_human,        # 사람 상담원 연결 Tool
]

# Agent 생성
agent = create_agent(
    model,
    tools=all_tools,
    # Agent 실행 중 상태를 구조적으로 관리하기 위한 타입 정의
    state_schema=SupportState,
    # --------------------------------------------------------
    # Middleware 설정
    # --------------------------------------------------------
    # apply_step_config:
    #   - 현재 단계 확인
    #   - 시스템 프롬프트 변경
    #   - Tool 사용 제한
    middleware=[apply_step_config],
    checkpointer=InMemorySaver(),
)

agent

# %% [markdown]
# ## 7. 멀티 턴 대화 실행
#
# 여러 턴에 걸쳐 상태 전환을 확인합니다.

# %%
from langchain_core.messages import HumanMessage
import uuid  # 고유 ID 생성을 위한 모듈

# 스레드 ID 생성
#   → Agent 대화 세션 식별자
#   → Checkpointer 가 상태를 저장할 때 사용됨
#   → 같은 thread_id 를 사용하면 이전 상태가 이어짐
thread_id = str(uuid.uuid4())

config = {"configurable": {"thread_id": thread_id}}

print("=" * 80)
print("턴 1: 보증 확인 - warranty_collector 단계에서 시작")
print("=" * 80)

# Agent 실행
result = agent.invoke(
    {
        "messages": [
            HumanMessage(
                content="안녕하세요, 제 휴대폰 화면이 깨졌어요."
            )
        ]
    },
    config=config
)

# Agent 응답 메시지 출력
for msg in result["messages"]:
    # pretty_print 메서드가 있으면 보기 좋게 출력
    if hasattr(msg, 'pretty_print'):
        msg.pretty_print()
    else:
        print(msg)

# 현재 Workflow 단계 출력
# current_step:
#   → Agent 상태(State)에 저장된 현재 단계

print(f"\n현재 단계: {result.get('current_step', 'N/A')}")
# Out:
# ================================================================================
# 턴 1: 보증 확인 - warranty_collector 단계에서 시작
# ================================================================================
# ================================ Human Message =================================
#
# 안녕하세요, 제 휴대폰 화면이 깨졌어요.
# ================================== Ai Message ==================================
#
# 안녕하세요! 불편을 드려 죄송해요 — 먼저 기기가 아직 보증 기간 내에 있나요? (예/아니오로 답해 주세요.)
#
# 현재 단계: N/A

# %% [markdown]
# ### 턴 2: 보증 상태 응답

# %%
print("\n" + "=" * 80)
print("턴 2: 보증 상태 응답")
print("=" * 80)

result = agent.invoke(
    {"messages": [HumanMessage(content="네, 아직 보증 기간 내입니다.")]},
    config=config
)

for msg in result["messages"]:
    if hasattr(msg, 'pretty_print'):
        msg.pretty_print()
    else:
        print(msg)

print(f"\n현재 단계: {result.get('current_step', 'N/A')}")
print(f"보증 상태: {result.get('warranty_status', 'N/A')}")
# Out:
# ================================================================================
# 턴 2: 보증 상태 응답
# ================================================================================
# ================================ Human Message =================================
#
# 안녕하세요, 제 휴대폰 화면이 깨졌어요.
# ================================== Ai Message ==================================
#
# 안녕하세요! 불편을 드려 죄송해요 — 먼저 기기가 아직 보증 기간 내에 있나요? (예/아니오로 답해 주세요.)
# ================================ Human Message =================================
#
# 네, 아직 보증 기간 내입니다.
# ================================== Ai Message ==================================
# Tool Calls:
#   record_warranty_status (call_bZ0VDKUTYBzWvC7omfZ89jCE)
#  Call ID: call_bZ0VDKUTYBzWvC7omfZ89jCE
#   Args:
#     status: in_warranty
# ================================= Tool Message =================================
# Name: record_warranty_status
#
# Warranty status recorded as: in_warranty
# ================================== Ai Message ==================================
# Tool Calls:
#   record_issue_type (call_8Wy6jMKt82bsMh1jhPDVHxOI)
#  Call ID: call_8Wy6jMKt82bsMh1jhPDVHxOI
#   Args:
#     issue_type: hardware
# ================================= Tool Message =================================
# Name: record_issue_type
#
# Issue type recorded as: hardware
# ================================== Ai Message ==================================
# Tool Calls:
#   provide_solution (call_h7fOE16Ynk9LPdPP7TuYyvam)
#  Call ID: call_h7fOE16Ynk9LPdPP7TuYyvam
#   Args:
#     solution: 안내드립니다 — 보증 기간 내 하드웨어(화면 파손) 수리 절차 및 다음 단계 안내
#
# 요약
# - 현재 보증 기간 내이므로 보증수리 절차로 접수해 드릴 수 있습니다. 다만, 일반적으로 ‘화면 파손(낙하/충격 등 물리적 손상)’은 제조 결함과 달라 기본 보증에서 제외될 수 있습니다. 수리 접수 후 기술진이 상태를 확인하여 보증 적용 여부를 확정하고, 보증 미적용 시 수리비 견적을 안내해 드리겠습니다.
#
# 수리 접수 전 준비물(필수 및 권장)
# 1. 기기 정보: 모델명, 일련번호(S/N) 또는 IMEI
# 2. 구매 증빙: 영수증 또는 주문번호(구매일 확인용)
# 3. 파손 상태 사진: 전면 전체, 가까이에서 찍은 파손 부위, 뒷면(필요시)
# 4. 연락처 및 수리 받을 주소
# 5. 데이터 백업 권장: 연락 및 수리 과정에서 데이터 손실이 발생할 수 있으니 iCloud/Google/PC로 반드시 백업해 주세요.
# 6. 악세서리(케이스/필름/심카드/메모리카드)는 제거 후 보내 주세요.
#
# 수리 접수 방법(선택 가능)
# - 온라인 접수: 당사 수리 신청 페이지에서 접수(접수 후 배송 라벨 발급 또는 지정 택배 픽업 안내)
# - 전화/채팅 접수: 고객센터로 접수하여 근처 공인 서비스 센터 방문 예약 또는 택배 수거 요청
# - 방문 접수: 공인 서비스 센터 직접 방문 (방문 전 예약 권장)
#
# 수리 절차 및 기간
# 1. 접수 → 2. 기술진 진단(도착 후 1–3 영업일) → 3. 보증 적용 여부 통보 및 수리 진행(보증 적용 시 무상 수리) 또는 비용 견적 제공(보증 미적용 시) → 4. 수리 완료 후 발송
# - 일반적으로 접수 후 전송·진단·수리·반송까지 약 5–10 영업일 소요(부품 수급 상황에 따라 변동)
#
# 비용 처리
# - 제조 결함으로 판정되면 무상 수리(보증 내 적용)
# - 물리적 손상(파손 등)으로 판정되면 유상 수리(사전 견적 승인이 필요)
# - 수리 전 고객 동의 없이 비용이 청구되지는 않습니다. 견적을 확인하신 후 진행 여부를 선택하실 수 있습니다.
#
# 다음에 제가 도와드릴 수 있는 것
# - 지금 바로 수리 접수를 진행해 드릴 수 있습니다. 접수 진행을 원하시면 아래 정보를 답장해 주세요:
#   • 모델명, IMEI 또는 S/N
#   • 구매 영수증 사진(또는 주문번호·구매일)
#   • 파손 사진(전면/근접)
#   • 연락처, 수령 주소
#
# 원하시면 먼저 원격으로 간단 점검 안내(화면 터치 반응 여부 등)를 도와드릴 수 있습니다. 어떻게 진행할까요?
# ================================= Tool Message =================================
# Name: provide_solution
#
# Solution provided: 안내드립니다 — 보증 기간 내 하드웨어(화면 파손) 수리 절차 및 다음 단계 안내
#
# 요약
# - 현재 보증 기간 내이므로 보증수리 절차로 접수해 드릴 수 있습니다. 다만, 일반적으로 ‘화면 파손(낙하/충격 등 물리적 손상)’은 제조 결함과 달라 기본 보증에서 제외될 수 있습니다. 수리 접수 후 기술진이 상태를 확인하여 보증 적용 여부를 확정하고, 보증 미적용 시 수리비 견적을 안내해 드리겠습니다.
#
# 수리 접수 전 준비물(필수 및 권장)
# 1. 기기 정보: 모델명, 일련번호(S/N) 또는 IMEI
# 2. 구매 증빙: 영수증 또는 주문번호(구매일 확인용)
# 3. 파손 상태 사진: 전면 전체, 가까이에서 찍은 파손 부위, 뒷면(필요시)
# 4. 연락처 및 수리 받을 주소
# 5. 데이터 백업 권장: 연락 및 수리 과정에서 데이터 손실이 발생할 수 있으니 iCloud/Google/PC로 반드시 백업해 주세요.
# 6. 악세서리(케이스/필름/심카드/메모리카드)는 제거 후 보내 주세요.
#
# 수리 접수 방법(선택 가능)
# - 온라인 접수: 당사 수리 신청 페이지에서 접수(접수 후 배송 라벨 발급 또는 지정 택배 픽업 안내)
# - 전화/채팅 접수: 고객센터로 접수하여 근처 공인 서비스 센터 방문 예약 또는 택배 수거 요청
# - 방문 접수: 공인 서비스 센터 직접 방문 (방문 전 예약 권장)
#
# 수리 절차 및 기간
# 1. 접수 → 2. 기술진 진단(도착 후 1–3 영업일) → 3. 보증 적용 여부 통보 및 수리 진행(보증 적용 시 무상 수리) 또는 비용 견적 제공(보증 미적용 시) → 4. 수리 완료 후 발송
# - 일반적으로 접수 후 전송·진단·수리·반송까지 약 5–10 영업일 소요(부품 수급 상황에 따라 변동)
#
# 비용 처리
# - 제조 결함으로 판정되면 무상 수리(보증 내 적용)
# - 물리적 손상(파손 등)으로 판정되면 유상 수리(사전 견적 승인이 필요)
# - 수리 전 고객 동의 없이 비용이 청구되지는 않습니다. 견적을 확인하신 후 진행 여부를 선택하실 수 있습니다.
#
# 다음에 제가 도와드릴 수 있는 것
# - 지금 바로 수리 접수를 진행해 드릴 수 있습니다. 접수 진행을 원하시면 아래 정보를 답장해 주세요:
#   • 모델명, IMEI 또는 S/N
#   • 구매 영수증 사진(또는 주문번호·구매일)
#   • 파손 사진(전면/근접)
#   • 연락처, 수령 주소
#
# 원하시면 먼저 원격으로 간단 점검 안내(화면 터치 반응 여부 등)를 도와드릴 수 있습니다. 어떻게 진행할까요?
# ================================== Ai Message ==================================
#
# 감사합니다. 화면 파손은 하드웨어 이슈이며, 보증 기간 내이기 때문에 보증 수리 절차로 도와드리겠습니다.
#
# 다음 정보를 알려주시면 바로 수리 접수를 진행해 드리겠습니다.
# - 모델명 및 IMEI 또는 S/N
# - 구매 영수증(또는 주문번호/구매일) 사진
# - 파손된 화면 사진(전면 전체, 근접 촬영)
# - 연락처(휴대폰 번호) 및 수리 받으실 주소
#
# 원하시면 먼저 몇 가지 원격 점검을 안내해 드려 기기 상태(예: 터치 반응, 화면 깜빡임 등)를 확인한 뒤 접수할 수 있습니다. 어떻게 도와드릴까요?
#
# 현재 단계: resolution_specialist
# 보증 상태: in_warranty

# %% [markdown]
# ### 턴 3: 이슈 설명

# %%
print("\n" + "=" * 80)
print("턴 3: 이슈 설명")
print("=" * 80)

result = agent.invoke(
    {"messages": [HumanMessage(content="화면이 물리적으로 깨졌어요. 떨어뜨려서 그런 것 같아요.")]},
    config=config
)

for msg in result["messages"]:
    if hasattr(msg, 'pretty_print'):
        msg.pretty_print()
    else:
        print(msg)

print(f"\n현재 단계: {result.get('current_step', 'N/A')}")
print(f"이슈 유형: {result.get('issue_type', 'N/A')}")
# Out:
# ================================================================================
# 턴 3: 이슈 설명
# ================================================================================
# ================================ Human Message =================================
#
# 안녕하세요, 제 휴대폰 화면이 깨졌어요.
# ================================== Ai Message ==================================
#
# 안녕하세요! 불편을 드려 죄송해요 — 먼저 기기가 아직 보증 기간 내에 있나요? (예/아니오로 답해 주세요.)
# ================================ Human Message =================================
#
# 네, 아직 보증 기간 내입니다.
# ================================== Ai Message ==================================
# Tool Calls:
#   record_warranty_status (call_bZ0VDKUTYBzWvC7omfZ89jCE)
#  Call ID: call_bZ0VDKUTYBzWvC7omfZ89jCE
#   Args:
#     status: in_warranty
# ================================= Tool Message =================================
# Name: record_warranty_status
#
# Warranty status recorded as: in_warranty
# ================================== Ai Message ==================================
# Tool Calls:
#   record_issue_type (call_8Wy6jMKt82bsMh1jhPDVHxOI)
#  Call ID: call_8Wy6jMKt82bsMh1jhPDVHxOI
#   Args:
#     issue_type: hardware
# ================================= Tool Message =================================
# Name: record_issue_type
#
# Issue type recorded as: hardware
# ================================== Ai Message ==================================
# Tool Calls:
#   provide_solution (call_h7fOE16Ynk9LPdPP7TuYyvam)
#  Call ID: call_h7fOE16Ynk9LPdPP7TuYyvam
#   Args:
#     solution: 안내드립니다 — 보증 기간 내 하드웨어(화면 파손) 수리 절차 및 다음 단계 안내
#
# 요약
# - 현재 보증 기간 내이므로 보증수리 절차로 접수해 드릴 수 있습니다. 다만, 일반적으로 ‘화면 파손(낙하/충격 등 물리적 손상)’은 제조 결함과 달라 기본 보증에서 제외될 수 있습니다. 수리 접수 후 기술진이 상태를 확인하여 보증 적용 여부를 확정하고, 보증 미적용 시 수리비 견적을 안내해 드리겠습니다.
#
# 수리 접수 전 준비물(필수 및 권장)
# 1. 기기 정보: 모델명, 일련번호(S/N) 또는 IMEI
# 2. 구매 증빙: 영수증 또는 주문번호(구매일 확인용)
# 3. 파손 상태 사진: 전면 전체, 가까이에서 찍은 파손 부위, 뒷면(필요시)
# 4. 연락처 및 수리 받을 주소
# 5. 데이터 백업 권장: 연락 및 수리 과정에서 데이터 손실이 발생할 수 있으니 iCloud/Google/PC로 반드시 백업해 주세요.
# 6. 악세서리(케이스/필름/심카드/메모리카드)는 제거 후 보내 주세요.
#
# 수리 접수 방법(선택 가능)
# - 온라인 접수: 당사 수리 신청 페이지에서 접수(접수 후 배송 라벨 발급 또는 지정 택배 픽업 안내)
# - 전화/채팅 접수: 고객센터로 접수하여 근처 공인 서비스 센터 방문 예약 또는 택배 수거 요청
# - 방문 접수: 공인 서비스 센터 직접 방문 (방문 전 예약 권장)
#
# 수리 절차 및 기간
# 1. 접수 → 2. 기술진 진단(도착 후 1–3 영업일) → 3. 보증 적용 여부 통보 및 수리 진행(보증 적용 시 무상 수리) 또는 비용 견적 제공(보증 미적용 시) → 4. 수리 완료 후 발송
# - 일반적으로 접수 후 전송·진단·수리·반송까지 약 5–10 영업일 소요(부품 수급 상황에 따라 변동)
#
# 비용 처리
# - 제조 결함으로 판정되면 무상 수리(보증 내 적용)
# - 물리적 손상(파손 등)으로 판정되면 유상 수리(사전 견적 승인이 필요)
# - 수리 전 고객 동의 없이 비용이 청구되지는 않습니다. 견적을 확인하신 후 진행 여부를 선택하실 수 있습니다.
#
# 다음에 제가 도와드릴 수 있는 것
# - 지금 바로 수리 접수를 진행해 드릴 수 있습니다. 접수 진행을 원하시면 아래 정보를 답장해 주세요:
#   • 모델명, IMEI 또는 S/N
#   • 구매 영수증 사진(또는 주문번호·구매일)
#   • 파손 사진(전면/근접)
#   • 연락처, 수령 주소
#
# 원하시면 먼저 원격으로 간단 점검 안내(화면 터치 반응 여부 등)를 도와드릴 수 있습니다. 어떻게 진행할까요?
# ================================= Tool Message =================================
# Name: provide_solution
#
# Solution provided: 안내드립니다 — 보증 기간 내 하드웨어(화면 파손) 수리 절차 및 다음 단계 안내
#
# 요약
# - 현재 보증 기간 내이므로 보증수리 절차로 접수해 드릴 수 있습니다. 다만, 일반적으로 ‘화면 파손(낙하/충격 등 물리적 손상)’은 제조 결함과 달라 기본 보증에서 제외될 수 있습니다. 수리 접수 후 기술진이 상태를 확인하여 보증 적용 여부를 확정하고, 보증 미적용 시 수리비 견적을 안내해 드리겠습니다.
#
# 수리 접수 전 준비물(필수 및 권장)
# 1. 기기 정보: 모델명, 일련번호(S/N) 또는 IMEI
# 2. 구매 증빙: 영수증 또는 주문번호(구매일 확인용)
# 3. 파손 상태 사진: 전면 전체, 가까이에서 찍은 파손 부위, 뒷면(필요시)
# 4. 연락처 및 수리 받을 주소
# 5. 데이터 백업 권장: 연락 및 수리 과정에서 데이터 손실이 발생할 수 있으니 iCloud/Google/PC로 반드시 백업해 주세요.
# 6. 악세서리(케이스/필름/심카드/메모리카드)는 제거 후 보내 주세요.
#
# 수리 접수 방법(선택 가능)
# - 온라인 접수: 당사 수리 신청 페이지에서 접수(접수 후 배송 라벨 발급 또는 지정 택배 픽업 안내)
# - 전화/채팅 접수: 고객센터로 접수하여 근처 공인 서비스 센터 방문 예약 또는 택배 수거 요청
# - 방문 접수: 공인 서비스 센터 직접 방문 (방문 전 예약 권장)
#
# 수리 절차 및 기간
# 1. 접수 → 2. 기술진 진단(도착 후 1–3 영업일) → 3. 보증 적용 여부 통보 및 수리 진행(보증 적용 시 무상 수리) 또는 비용 견적 제공(보증 미적용 시) → 4. 수리 완료 후 발송
# - 일반적으로 접수 후 전송·진단·수리·반송까지 약 5–10 영업일 소요(부품 수급 상황에 따라 변동)
#
# 비용 처리
# - 제조 결함으로 판정되면 무상 수리(보증 내 적용)
# - 물리적 손상(파손 등)으로 판정되면 유상 수리(사전 견적 승인이 필요)
# - 수리 전 고객 동의 없이 비용이 청구되지는 않습니다. 견적을 확인하신 후 진행 여부를 선택하실 수 있습니다.
#
# 다음에 제가 도와드릴 수 있는 것
# - 지금 바로 수리 접수를 진행해 드릴 수 있습니다. 접수 진행을 원하시면 아래 정보를 답장해 주세요:
#   • 모델명, IMEI 또는 S/N
#   • 구매 영수증 사진(또는 주문번호·구매일)
#   • 파손 사진(전면/근접)
#   • 연락처, 수령 주소
#
# 원하시면 먼저 원격으로 간단 점검 안내(화면 터치 반응 여부 등)를 도와드릴 수 있습니다. 어떻게 진행할까요?
# ================================== Ai Message ==================================
#
# 감사합니다. 화면 파손은 하드웨어 이슈이며, 보증 기간 내이기 때문에 보증 수리 절차로 도와드리겠습니다.
#
# 다음 정보를 알려주시면 바로 수리 접수를 진행해 드리겠습니다.
# - 모델명 및 IMEI 또는 S/N
# - 구매 영수증(또는 주문번호/구매일) 사진
# - 파손된 화면 사진(전면 전체, 근접 촬영)
# - 연락처(휴대폰 번호) 및 수리 받으실 주소
#
# 원하시면 먼저 몇 가지 원격 점검을 안내해 드려 기기 상태(예: 터치 반응, 화면 깜빡임 등)를 확인한 뒤 접수할 수 있습니다. 어떻게 도와드릴까요?
# ================================ Human Message =================================
#
# 화면이 물리적으로 깨졌어요. 떨어뜨려서 그런 것 같아요.
# ================================== Ai Message ==================================
# Tool Calls:
#   provide_solution (call_cWFJJWl1Vc9jBhx0VdxZwZgs)
#  Call ID: call_cWFJJWl1Vc9jBhx0VdxZwZgs
#   Args:
#     solution: 안내드립니다 — 물리적(낙하)로 인한 화면 파손 관련 절차 및 다음 단계 안내
#
# 요약
# - 떨어뜨림으로 인한 화면 파손은 ‘우발적 물리적 손상(accidental damage)’로 분류되는 경우가 많아, 기본 제조 보증에서 제외될 가능성이 높습니다. 그러나 기기가 보증 기간 내이므로 우선 수리 접수를 통해 기술 진단을 진행하고 보증 적용 여부를 최종 판단하겠습니다. 보증 미적용 시 수리비 견적을 안내해 드리며, 고객 승인 후 수리 진행합니다.
#
# 필요한 준비물(접수 전)
# 1. 모델명 및 IMEI 또는 S/N
# 2. 구매 증빙(영수증/주문번호/구매일) — 보증 확인용
# 3. 파손 사진(전면 전체 사진과 파손 부위 근접 사진) — 접수 시 필수
# 4. 연락처(휴대폰 번호) 및 수리 받으실 주소
# 5. 데이터 백업 권장(사진/중요자료 등) — 수리 과정에서 데이터 손실 가능성 있음
# 6. SIM 카드 및 외장 메모리 제거, 케이스/필름 제거
#
# 접수 방법(선택)
# - 온라인 접수: 웹 포털에서 사진·문서 업로드 후 택배 픽업 또는 고객 직접 발송
# - 전화/채팅 접수: 상담원이 근처 공인 서비스 센터 예약 또는 택배 수거 신청 지원
# - 방문 접수: 공인 서비스 센터 직접 방문(방문 전 예약 권장)
#
# 진단 및 비용 처리 방식
# 1. 수리 접수 → 기술진 진단(도착 후 1–3 영업일 내) → 보증 적용 여부 통보
# 2. 보증 적용: 제조 결함으로 판정될 경우 무상 수리
# 3. 보증 미적용(대부분의 낙하/충격 파손 경우 해당): 유상 수리(화면 교체 등). 수리 전 견적을 제공하며, 고객 승인 후 진행
# 4. 고객 동의 없이 추가 비용 청구 없음
#
# 수리 기간
# - 일반적으로 접수부터 반송까지 5–10 영업일 소요(부품 수급·센터 혼잡도에 따라 변동). 급한 경우 우선 처리 요청 가능(가능 여부는 센터 사정에 따름).
#
# 추가 안내/유의사항
# - 일부 모델은 화면만 교체 가능한 경우와 본체 어셈블리 교체가 필요한 경우로 비용 차이가 큽니다. 최종 비용은 진단 후 확정됩니다.
# - 기기 내부 손상(예: 보드 손상, 센서 불량 등)이 발견되면 추가 수리 비용이 발생할 수 있습니다.
# - 셀프 수리(비인가 수리 업체 이용)는 보증 무효 사유가 될 수 있으니 권장하지 않습니다.
#
# 지금 도와드릴 수 있는 것
# - 바로 수리 접수를 진행해 드리겠습니다. 접수 원하시면 아래 정보를 보내 주세요:
#   • 모델명, IMEI 또는 S/N
#   • 구매 영수증(또는 주문번호/구매일) 사진
#   • 파손 사진(전면 전체, 근접)
#   • 연락처, 수리 받으실 주소
# - 원하시면 먼저 원격으로 간단 점검(터치 반응, 화면 깜빡임 여부 등)을 안내해 드려 현재 상태를 확인한 뒤 접수할 수도 있습니다.
#
# 진행을 원하시면 어떻게 접수할지(온라인/방문/픽업)와 함께 위 정보를 알려 주세요. 제가 접수 절차를 바로 도와 드리겠습니다.
# ================================= Tool Message =================================
# Name: provide_solution
#
# Solution provided: 안내드립니다 — 물리적(낙하)로 인한 화면 파손 관련 절차 및 다음 단계 안내
#
# 요약
# - 떨어뜨림으로 인한 화면 파손은 ‘우발적 물리적 손상(accidental damage)’로 분류되는 경우가 많아, 기본 제조 보증에서 제외될 가능성이 높습니다. 그러나 기기가 보증 기간 내이므로 우선 수리 접수를 통해 기술 진단을 진행하고 보증 적용 여부를 최종 판단하겠습니다. 보증 미적용 시 수리비 견적을 안내해 드리며, 고객 승인 후 수리 진행합니다.
#
# 필요한 준비물(접수 전)
# 1. 모델명 및 IMEI 또는 S/N
# 2. 구매 증빙(영수증/주문번호/구매일) — 보증 확인용
# 3. 파손 사진(전면 전체 사진과 파손 부위 근접 사진) — 접수 시 필수
# 4. 연락처(휴대폰 번호) 및 수리 받으실 주소
# 5. 데이터 백업 권장(사진/중요자료 등) — 수리 과정에서 데이터 손실 가능성 있음
# 6. SIM 카드 및 외장 메모리 제거, 케이스/필름 제거
#
# 접수 방법(선택)
# - 온라인 접수: 웹 포털에서 사진·문서 업로드 후 택배 픽업 또는 고객 직접 발송
# - 전화/채팅 접수: 상담원이 근처 공인 서비스 센터 예약 또는 택배 수거 신청 지원
# - 방문 접수: 공인 서비스 센터 직접 방문(방문 전 예약 권장)
#
# 진단 및 비용 처리 방식
# 1. 수리 접수 → 기술진 진단(도착 후 1–3 영업일 내) → 보증 적용 여부 통보
# 2. 보증 적용: 제조 결함으로 판정될 경우 무상 수리
# 3. 보증 미적용(대부분의 낙하/충격 파손 경우 해당): 유상 수리(화면 교체 등). 수리 전 견적을 제공하며, 고객 승인 후 진행
# 4. 고객 동의 없이 추가 비용 청구 없음
#
# 수리 기간
# - 일반적으로 접수부터 반송까지 5–10 영업일 소요(부품 수급·센터 혼잡도에 따라 변동). 급한 경우 우선 처리 요청 가능(가능 여부는 센터 사정에 따름).
#
# 추가 안내/유의사항
# - 일부 모델은 화면만 교체 가능한 경우와 본체 어셈블리 교체가 필요한 경우로 비용 차이가 큽니다. 최종 비용은 진단 후 확정됩니다.
# - 기기 내부 손상(예: 보드 손상, 센서 불량 등)이 발견되면 추가 수리 비용이 발생할 수 있습니다.
# - 셀프 수리(비인가 수리 업체 이용)는 보증 무효 사유가 될 수 있으니 권장하지 않습니다.
#
# 지금 도와드릴 수 있는 것
# - 바로 수리 접수를 진행해 드리겠습니다. 접수 원하시면 아래 정보를 보내 주세요:
#   • 모델명, IMEI 또는 S/N
#   • 구매 영수증(또는 주문번호/구매일) 사진
#   • 파손 사진(전면 전체, 근접)
#   • 연락처, 수리 받으실 주소
# - 원하시면 먼저 원격으로 간단 점검(터치 반응, 화면 깜빡임 여부 등)을 안내해 드려 현재 상태를 확인한 뒤 접수할 수도 있습니다.
#
# 진행을 원하시면 어떻게 접수할지(온라인/방문/픽업)와 함께 위 정보를 알려 주세요. 제가 접수 절차를 바로 도와 드리겠습니다.
# ================================== Ai Message ==================================
#
# 알려주셔서 감사합니다. 물리적 낙하로 인한 화면 파손인 경우, 보증 적용이 어려울 가능성이 높지만 우선 보증 수리로 접수해 진단을 진행한 뒤 최종 판단하겠습니다.
#
# 진행을 원하시면 아래 정보를 보내 주세요.
# - 모델명 및 IMEI 또는 S/N
# - 구매 영수증(또는 주문번호/구매일) 사진
# - 파손된 화면 사진(전면 전체, 근접 촬영)
# - 연락처(휴대폰 번호) 및 수리 받으실 주소
#
# 원하시면 먼저 원격 점검(터치 반응/화면 깜빡임 등)을 안내해 드릴게요. 어느 방식으로 진행할까요?
#
# 현재 단계: resolution_specialist
# 이슈 유형: hardware

# %% [markdown]
# ### 턴 4: 해결책 제공

# %%
print("\n" + "=" * 80)
print("턴 4: 해결책 제공")
print("=" * 80)

result = agent.invoke(
    {"messages": [HumanMessage(content="어떻게 해야 하나요?")]},
    config=config
)

for msg in result["messages"]:
    if hasattr(msg, 'pretty_print'):
        msg.pretty_print()
    else:
        print(msg)

print(f"\n현재 단계: {result.get('current_step', 'N/A')}")
# Out:
# ================================================================================
# 턴 4: 해결책 제공
# ================================================================================
# ================================ Human Message =================================
#
# 안녕하세요, 제 휴대폰 화면이 깨졌어요.
# ================================== Ai Message ==================================
#
# 안녕하세요! 불편을 드려 죄송해요 — 먼저 기기가 아직 보증 기간 내에 있나요? (예/아니오로 답해 주세요.)
# ================================ Human Message =================================
#
# 네, 아직 보증 기간 내입니다.
# ================================== Ai Message ==================================
# Tool Calls:
#   record_warranty_status (call_bZ0VDKUTYBzWvC7omfZ89jCE)
#  Call ID: call_bZ0VDKUTYBzWvC7omfZ89jCE
#   Args:
#     status: in_warranty
# ================================= Tool Message =================================
# Name: record_warranty_status
#
# Warranty status recorded as: in_warranty
# ================================== Ai Message ==================================
# Tool Calls:
#   record_issue_type (call_8Wy6jMKt82bsMh1jhPDVHxOI)
#  Call ID: call_8Wy6jMKt82bsMh1jhPDVHxOI
#   Args:
#     issue_type: hardware
# ================================= Tool Message =================================
# Name: record_issue_type
#
# Issue type recorded as: hardware
# ================================== Ai Message ==================================
# Tool Calls:
#   provide_solution (call_h7fOE16Ynk9LPdPP7TuYyvam)
#  Call ID: call_h7fOE16Ynk9LPdPP7TuYyvam
#   Args:
#     solution: 안내드립니다 — 보증 기간 내 하드웨어(화면 파손) 수리 절차 및 다음 단계 안내
#
# 요약
# - 현재 보증 기간 내이므로 보증수리 절차로 접수해 드릴 수 있습니다. 다만, 일반적으로 ‘화면 파손(낙하/충격 등 물리적 손상)’은 제조 결함과 달라 기본 보증에서 제외될 수 있습니다. 수리 접수 후 기술진이 상태를 확인하여 보증 적용 여부를 확정하고, 보증 미적용 시 수리비 견적을 안내해 드리겠습니다.
#
# 수리 접수 전 준비물(필수 및 권장)
# 1. 기기 정보: 모델명, 일련번호(S/N) 또는 IMEI
# 2. 구매 증빙: 영수증 또는 주문번호(구매일 확인용)
# 3. 파손 상태 사진: 전면 전체, 가까이에서 찍은 파손 부위, 뒷면(필요시)
# 4. 연락처 및 수리 받을 주소
# 5. 데이터 백업 권장: 연락 및 수리 과정에서 데이터 손실이 발생할 수 있으니 iCloud/Google/PC로 반드시 백업해 주세요.
# 6. 악세서리(케이스/필름/심카드/메모리카드)는 제거 후 보내 주세요.
#
# 수리 접수 방법(선택 가능)
# - 온라인 접수: 당사 수리 신청 페이지에서 접수(접수 후 배송 라벨 발급 또는 지정 택배 픽업 안내)
# - 전화/채팅 접수: 고객센터로 접수하여 근처 공인 서비스 센터 방문 예약 또는 택배 수거 요청
# - 방문 접수: 공인 서비스 센터 직접 방문 (방문 전 예약 권장)
#
# 수리 절차 및 기간
# 1. 접수 → 2. 기술진 진단(도착 후 1–3 영업일) → 3. 보증 적용 여부 통보 및 수리 진행(보증 적용 시 무상 수리) 또는 비용 견적 제공(보증 미적용 시) → 4. 수리 완료 후 발송
# - 일반적으로 접수 후 전송·진단·수리·반송까지 약 5–10 영업일 소요(부품 수급 상황에 따라 변동)
#
# 비용 처리
# - 제조 결함으로 판정되면 무상 수리(보증 내 적용)
# - 물리적 손상(파손 등)으로 판정되면 유상 수리(사전 견적 승인이 필요)
# - 수리 전 고객 동의 없이 비용이 청구되지는 않습니다. 견적을 확인하신 후 진행 여부를 선택하실 수 있습니다.
#
# 다음에 제가 도와드릴 수 있는 것
# - 지금 바로 수리 접수를 진행해 드릴 수 있습니다. 접수 진행을 원하시면 아래 정보를 답장해 주세요:
#   • 모델명, IMEI 또는 S/N
#   • 구매 영수증 사진(또는 주문번호·구매일)
#   • 파손 사진(전면/근접)
#   • 연락처, 수령 주소
#
# 원하시면 먼저 원격으로 간단 점검 안내(화면 터치 반응 여부 등)를 도와드릴 수 있습니다. 어떻게 진행할까요?
# ================================= Tool Message =================================
# Name: provide_solution
#
# Solution provided: 안내드립니다 — 보증 기간 내 하드웨어(화면 파손) 수리 절차 및 다음 단계 안내
#
# 요약
# - 현재 보증 기간 내이므로 보증수리 절차로 접수해 드릴 수 있습니다. 다만, 일반적으로 ‘화면 파손(낙하/충격 등 물리적 손상)’은 제조 결함과 달라 기본 보증에서 제외될 수 있습니다. 수리 접수 후 기술진이 상태를 확인하여 보증 적용 여부를 확정하고, 보증 미적용 시 수리비 견적을 안내해 드리겠습니다.
#
# 수리 접수 전 준비물(필수 및 권장)
# 1. 기기 정보: 모델명, 일련번호(S/N) 또는 IMEI
# 2. 구매 증빙: 영수증 또는 주문번호(구매일 확인용)
# 3. 파손 상태 사진: 전면 전체, 가까이에서 찍은 파손 부위, 뒷면(필요시)
# 4. 연락처 및 수리 받을 주소
# 5. 데이터 백업 권장: 연락 및 수리 과정에서 데이터 손실이 발생할 수 있으니 iCloud/Google/PC로 반드시 백업해 주세요.
# 6. 악세서리(케이스/필름/심카드/메모리카드)는 제거 후 보내 주세요.
#
# 수리 접수 방법(선택 가능)
# - 온라인 접수: 당사 수리 신청 페이지에서 접수(접수 후 배송 라벨 발급 또는 지정 택배 픽업 안내)
# - 전화/채팅 접수: 고객센터로 접수하여 근처 공인 서비스 센터 방문 예약 또는 택배 수거 요청
# - 방문 접수: 공인 서비스 센터 직접 방문 (방문 전 예약 권장)
#
# 수리 절차 및 기간
# 1. 접수 → 2. 기술진 진단(도착 후 1–3 영업일) → 3. 보증 적용 여부 통보 및 수리 진행(보증 적용 시 무상 수리) 또는 비용 견적 제공(보증 미적용 시) → 4. 수리 완료 후 발송
# - 일반적으로 접수 후 전송·진단·수리·반송까지 약 5–10 영업일 소요(부품 수급 상황에 따라 변동)
#
# 비용 처리
# - 제조 결함으로 판정되면 무상 수리(보증 내 적용)
# - 물리적 손상(파손 등)으로 판정되면 유상 수리(사전 견적 승인이 필요)
# - 수리 전 고객 동의 없이 비용이 청구되지는 않습니다. 견적을 확인하신 후 진행 여부를 선택하실 수 있습니다.
#
# 다음에 제가 도와드릴 수 있는 것
# - 지금 바로 수리 접수를 진행해 드릴 수 있습니다. 접수 진행을 원하시면 아래 정보를 답장해 주세요:
#   • 모델명, IMEI 또는 S/N
#   • 구매 영수증 사진(또는 주문번호·구매일)
#   • 파손 사진(전면/근접)
#   • 연락처, 수령 주소
#
# 원하시면 먼저 원격으로 간단 점검 안내(화면 터치 반응 여부 등)를 도와드릴 수 있습니다. 어떻게 진행할까요?
# ================================== Ai Message ==================================
#
# 감사합니다. 화면 파손은 하드웨어 이슈이며, 보증 기간 내이기 때문에 보증 수리 절차로 도와드리겠습니다.
#
# 다음 정보를 알려주시면 바로 수리 접수를 진행해 드리겠습니다.
# - 모델명 및 IMEI 또는 S/N
# - 구매 영수증(또는 주문번호/구매일) 사진
# - 파손된 화면 사진(전면 전체, 근접 촬영)
# - 연락처(휴대폰 번호) 및 수리 받으실 주소
#
# 원하시면 먼저 몇 가지 원격 점검을 안내해 드려 기기 상태(예: 터치 반응, 화면 깜빡임 등)를 확인한 뒤 접수할 수 있습니다. 어떻게 도와드릴까요?
# ================================ Human Message =================================
#
# 화면이 물리적으로 깨졌어요. 떨어뜨려서 그런 것 같아요.
# ================================== Ai Message ==================================
# Tool Calls:
#   provide_solution (call_cWFJJWl1Vc9jBhx0VdxZwZgs)
#  Call ID: call_cWFJJWl1Vc9jBhx0VdxZwZgs
#   Args:
#     solution: 안내드립니다 — 물리적(낙하)로 인한 화면 파손 관련 절차 및 다음 단계 안내
#
# 요약
# - 떨어뜨림으로 인한 화면 파손은 ‘우발적 물리적 손상(accidental damage)’로 분류되는 경우가 많아, 기본 제조 보증에서 제외될 가능성이 높습니다. 그러나 기기가 보증 기간 내이므로 우선 수리 접수를 통해 기술 진단을 진행하고 보증 적용 여부를 최종 판단하겠습니다. 보증 미적용 시 수리비 견적을 안내해 드리며, 고객 승인 후 수리 진행합니다.
#
# 필요한 준비물(접수 전)
# 1. 모델명 및 IMEI 또는 S/N
# 2. 구매 증빙(영수증/주문번호/구매일) — 보증 확인용
# 3. 파손 사진(전면 전체 사진과 파손 부위 근접 사진) — 접수 시 필수
# 4. 연락처(휴대폰 번호) 및 수리 받으실 주소
# 5. 데이터 백업 권장(사진/중요자료 등) — 수리 과정에서 데이터 손실 가능성 있음
# 6. SIM 카드 및 외장 메모리 제거, 케이스/필름 제거
#
# 접수 방법(선택)
# - 온라인 접수: 웹 포털에서 사진·문서 업로드 후 택배 픽업 또는 고객 직접 발송
# - 전화/채팅 접수: 상담원이 근처 공인 서비스 센터 예약 또는 택배 수거 신청 지원
# - 방문 접수: 공인 서비스 센터 직접 방문(방문 전 예약 권장)
#
# 진단 및 비용 처리 방식
# 1. 수리 접수 → 기술진 진단(도착 후 1–3 영업일 내) → 보증 적용 여부 통보
# 2. 보증 적용: 제조 결함으로 판정될 경우 무상 수리
# 3. 보증 미적용(대부분의 낙하/충격 파손 경우 해당): 유상 수리(화면 교체 등). 수리 전 견적을 제공하며, 고객 승인 후 진행
# 4. 고객 동의 없이 추가 비용 청구 없음
#
# 수리 기간
# - 일반적으로 접수부터 반송까지 5–10 영업일 소요(부품 수급·센터 혼잡도에 따라 변동). 급한 경우 우선 처리 요청 가능(가능 여부는 센터 사정에 따름).
#
# 추가 안내/유의사항
# - 일부 모델은 화면만 교체 가능한 경우와 본체 어셈블리 교체가 필요한 경우로 비용 차이가 큽니다. 최종 비용은 진단 후 확정됩니다.
# - 기기 내부 손상(예: 보드 손상, 센서 불량 등)이 발견되면 추가 수리 비용이 발생할 수 있습니다.
# - 셀프 수리(비인가 수리 업체 이용)는 보증 무효 사유가 될 수 있으니 권장하지 않습니다.
#
# 지금 도와드릴 수 있는 것
# - 바로 수리 접수를 진행해 드리겠습니다. 접수 원하시면 아래 정보를 보내 주세요:
#   • 모델명, IMEI 또는 S/N
#   • 구매 영수증(또는 주문번호/구매일) 사진
#   • 파손 사진(전면 전체, 근접)
#   • 연락처, 수리 받으실 주소
# - 원하시면 먼저 원격으로 간단 점검(터치 반응, 화면 깜빡임 여부 등)을 안내해 드려 현재 상태를 확인한 뒤 접수할 수도 있습니다.
#
# 진행을 원하시면 어떻게 접수할지(온라인/방문/픽업)와 함께 위 정보를 알려 주세요. 제가 접수 절차를 바로 도와 드리겠습니다.
# ================================= Tool Message =================================
# Name: provide_solution
#
# Solution provided: 안내드립니다 — 물리적(낙하)로 인한 화면 파손 관련 절차 및 다음 단계 안내
#
# 요약
# - 떨어뜨림으로 인한 화면 파손은 ‘우발적 물리적 손상(accidental damage)’로 분류되는 경우가 많아, 기본 제조 보증에서 제외될 가능성이 높습니다. 그러나 기기가 보증 기간 내이므로 우선 수리 접수를 통해 기술 진단을 진행하고 보증 적용 여부를 최종 판단하겠습니다. 보증 미적용 시 수리비 견적을 안내해 드리며, 고객 승인 후 수리 진행합니다.
#
# 필요한 준비물(접수 전)
# 1. 모델명 및 IMEI 또는 S/N
# 2. 구매 증빙(영수증/주문번호/구매일) — 보증 확인용
# 3. 파손 사진(전면 전체 사진과 파손 부위 근접 사진) — 접수 시 필수
# 4. 연락처(휴대폰 번호) 및 수리 받으실 주소
# 5. 데이터 백업 권장(사진/중요자료 등) — 수리 과정에서 데이터 손실 가능성 있음
# 6. SIM 카드 및 외장 메모리 제거, 케이스/필름 제거
#
# 접수 방법(선택)
# - 온라인 접수: 웹 포털에서 사진·문서 업로드 후 택배 픽업 또는 고객 직접 발송
# - 전화/채팅 접수: 상담원이 근처 공인 서비스 센터 예약 또는 택배 수거 신청 지원
# - 방문 접수: 공인 서비스 센터 직접 방문(방문 전 예약 권장)
#
# 진단 및 비용 처리 방식
# 1. 수리 접수 → 기술진 진단(도착 후 1–3 영업일 내) → 보증 적용 여부 통보
# 2. 보증 적용: 제조 결함으로 판정될 경우 무상 수리
# 3. 보증 미적용(대부분의 낙하/충격 파손 경우 해당): 유상 수리(화면 교체 등). 수리 전 견적을 제공하며, 고객 승인 후 진행
# 4. 고객 동의 없이 추가 비용 청구 없음
#
# 수리 기간
# - 일반적으로 접수부터 반송까지 5–10 영업일 소요(부품 수급·센터 혼잡도에 따라 변동). 급한 경우 우선 처리 요청 가능(가능 여부는 센터 사정에 따름).
#
# 추가 안내/유의사항
# - 일부 모델은 화면만 교체 가능한 경우와 본체 어셈블리 교체가 필요한 경우로 비용 차이가 큽니다. 최종 비용은 진단 후 확정됩니다.
# - 기기 내부 손상(예: 보드 손상, 센서 불량 등)이 발견되면 추가 수리 비용이 발생할 수 있습니다.
# - 셀프 수리(비인가 수리 업체 이용)는 보증 무효 사유가 될 수 있으니 권장하지 않습니다.
#
# 지금 도와드릴 수 있는 것
# - 바로 수리 접수를 진행해 드리겠습니다. 접수 원하시면 아래 정보를 보내 주세요:
#   • 모델명, IMEI 또는 S/N
#   • 구매 영수증(또는 주문번호/구매일) 사진
#   • 파손 사진(전면 전체, 근접)
#   • 연락처, 수리 받으실 주소
# - 원하시면 먼저 원격으로 간단 점검(터치 반응, 화면 깜빡임 여부 등)을 안내해 드려 현재 상태를 확인한 뒤 접수할 수도 있습니다.
#
# 진행을 원하시면 어떻게 접수할지(온라인/방문/픽업)와 함께 위 정보를 알려 주세요. 제가 접수 절차를 바로 도와 드리겠습니다.
# ================================== Ai Message ==================================
#
# 알려주셔서 감사합니다. 물리적 낙하로 인한 화면 파손인 경우, 보증 적용이 어려울 가능성이 높지만 우선 보증 수리로 접수해 진단을 진행한 뒤 최종 판단하겠습니다.
#
# 진행을 원하시면 아래 정보를 보내 주세요.
# - 모델명 및 IMEI 또는 S/N
# - 구매 영수증(또는 주문번호/구매일) 사진
# - 파손된 화면 사진(전면 전체, 근접 촬영)
# - 연락처(휴대폰 번호) 및 수리 받으실 주소
#
# 원하시면 먼저 원격 점검(터치 반응/화면 깜빡임 등)을 안내해 드릴게요. 어느 방식으로 진행할까요?
# ================================ Human Message =================================
#
# 어떻게 해야 하나요?
# ================================== Ai Message ==================================
# Tool Calls:
#   provide_solution (call_hnInVjWbXpwGthWIyvl5vv89)
#  Call ID: call_hnInVjWbXpwGthWIyvl5vv89
#   Args:
#     solution: 다음 단계(간단 요약)
# - 기기는 보증 기간 내이므로 보증 수리 접수로 우선 진행합니다. 다만 낙하·충격으로 인한 물리적 파손은 ‘우발적 손상’으로 보증 제외될 가능성이 높아, 접수 후 기술 진단으로 최종 판단합니다.
#
# 지금 바로 하실 것 (안전 및 데이터 보호)
# 1. 즉시 기기 전원 끄기(유리 파편으로 인한 상해 방지 및 추가 손상 방지).
# 2. 중요한 데이터 즉시 백업(iCloud/Google/PC 등) — 수리 중 데이터 손실 가능.
# 3. SIM 카드·외장메모리 제거, 케이스·화면필름 제거.
# 4. 깨진 유리로 다칠 위험이 있으면 보호장갑 착용 후 투명테이프로 파손 부위를 임시 고정(심한 경우 가까운 서비스센터 방문 권장).
# 5. 기기 침수 가능성 있으면 충전 및 전원 연결 금지.
#
# 수리 접수에 필요한 정보(미리 준비하면 접수 빨라집니다)
# - 모델명, IMEI 또는 S/N
# - 구매 영수증·주문번호·구매일(보증 확인용)
# - 파손 사진(전면 전체, 근접 촬영 각 1~2장)
# - 연락처(휴대번호)·수리 받을 주소
#
# 접수 방법(선택)
# - 온라인 접수(권장): 사진·서류 업로드 → 택배 픽업 또는 발송 안내 → 센터 진단
# - 방문 접수: 공인 서비스센터 예약 후 방문(예약 권장)
# - 택배 발송: 포장 후 지정 주소로 발송(포장 시 완충재 권장)
#
# 발생 절차 및 소요시간
# - 접수 → 도착 후 기술 진단(1–3 영업일) → 보증 적용 여부 통보 및 견적(유상 시) → 고객 승인 후 수리 → 반송
# - 보통 5–10 영업일(부품 수급·센터 상황에 따라 변동)
#
# 비용 및 결제
# - 제조 결함 판정 시 무상 수리(보증 적용)
# - 우발적 물리 손상 판정 시 유상 수리(수리 전 견적 제공, 고객 동의 후 진행)
# - 고객 동의 없이 비용이 청구되지 않습니다.
#
# 포장·발송 팁
# - 원래 박스가 있으면 사용 권장, 없으면 완충재(버블랩)로 고정 후 단단히 포장
# - 액세서리(케이스·필름)는 제거
#
# 제가 도와드릴 수 있는 것
# 1) 지금 바로 수리 접수 대행(온라인 택배 픽업 포함)을 원하시면 아래 정보를 알려 주세요:
#    • 모델명, IMEI/S/N
#    • 구매 영수증(또는 주문번호/구매일) 사진
#    • 파손 사진(전면 전체/근접)
#    • 연락처, 수리 받을 주소
# 2) 방문 접수를 원하시면 가까운 공인 서비스센터 예약 도와 드리겠습니다.
# 3) 먼저 원격으로 간단 점검(터치 반응, 화면 깜빡임 등)을 안내받고 싶으시면 알려 주세요.
#
# 어떻게 진행할지(접수 방법 선택)와 위 정보를 알려 주시면 제가 바로 접수 절차를 시작해 드리겠습니다.
# ================================= Tool Message =================================
# Name: provide_solution
#
# Solution provided: 다음 단계(간단 요약)
# - 기기는 보증 기간 내이므로 보증 수리 접수로 우선 진행합니다. 다만 낙하·충격으로 인한 물리적 파손은 ‘우발적 손상’으로 보증 제외될 가능성이 높아, 접수 후 기술 진단으로 최종 판단합니다.
#
# 지금 바로 하실 것 (안전 및 데이터 보호)
# 1. 즉시 기기 전원 끄기(유리 파편으로 인한 상해 방지 및 추가 손상 방지).
# 2. 중요한 데이터 즉시 백업(iCloud/Google/PC 등) — 수리 중 데이터 손실 가능.
# 3. SIM 카드·외장메모리 제거, 케이스·화면필름 제거.
# 4. 깨진 유리로 다칠 위험이 있으면 보호장갑 착용 후 투명테이프로 파손 부위를 임시 고정(심한 경우 가까운 서비스센터 방문 권장).
# 5. 기기 침수 가능성 있으면 충전 및 전원 연결 금지.
#
# 수리 접수에 필요한 정보(미리 준비하면 접수 빨라집니다)
# - 모델명, IMEI 또는 S/N
# - 구매 영수증·주문번호·구매일(보증 확인용)
# - 파손 사진(전면 전체, 근접 촬영 각 1~2장)
# - 연락처(휴대번호)·수리 받을 주소
#
# 접수 방법(선택)
# - 온라인 접수(권장): 사진·서류 업로드 → 택배 픽업 또는 발송 안내 → 센터 진단
# - 방문 접수: 공인 서비스센터 예약 후 방문(예약 권장)
# - 택배 발송: 포장 후 지정 주소로 발송(포장 시 완충재 권장)
#
# 발생 절차 및 소요시간
# - 접수 → 도착 후 기술 진단(1–3 영업일) → 보증 적용 여부 통보 및 견적(유상 시) → 고객 승인 후 수리 → 반송
# - 보통 5–10 영업일(부품 수급·센터 상황에 따라 변동)
#
# 비용 및 결제
# - 제조 결함 판정 시 무상 수리(보증 적용)
# - 우발적 물리 손상 판정 시 유상 수리(수리 전 견적 제공, 고객 동의 후 진행)
# - 고객 동의 없이 비용이 청구되지 않습니다.
#
# 포장·발송 팁
# - 원래 박스가 있으면 사용 권장, 없으면 완충재(버블랩)로 고정 후 단단히 포장
# - 액세서리(케이스·필름)는 제거
#
# 제가 도와드릴 수 있는 것
# 1) 지금 바로 수리 접수 대행(온라인 택배 픽업 포함)을 원하시면 아래 정보를 알려 주세요:
#    • 모델명, IMEI/S/N
#    • 구매 영수증(또는 주문번호/구매일) 사진
#    • 파손 사진(전면 전체/근접)
#    • 연락처, 수리 받을 주소
# 2) 방문 접수를 원하시면 가까운 공인 서비스센터 예약 도와 드리겠습니다.
# 3) 먼저 원격으로 간단 점검(터치 반응, 화면 깜빡임 등)을 안내받고 싶으시면 알려 주세요.
#
# 어떻게 진행할지(접수 방법 선택)와 위 정보를 알려 주시면 제가 바로 접수 절차를 시작해 드리겠습니다.
# ================================== Ai Message ==================================
# Tool Calls:
#   provide_solution (call_LExJAKLllR4hbw3CFIRECqf1)
#  Call ID: call_LExJAKLllR4hbw3CFIRECqf1
#   Args:
#     solution: 간단히 정리해 드리겠습니다 — 지금 바로 하실 일과 수리 절차
#
# 1) 즉시 조치(안전 및 데이터 보호)
# - 전원 끄기: 유리 파편으로 인한 상해/추가 손상 방지.
# - 데이터 백업: iCloud/Google/PC 등으로 즉시 백업(수리 중 데이터 손실 가능).
# - SIM 카드·외장메모리 제거, 케이스·필름 제거.
# - 파손 부위로 다칠 위험이 있으면 보호장갑 착용, 임시로 투명테이프로 고정.
#
# 2) 수리 접수 준비물
# - 모델명, IMEI 또는 S/N
# - 구매 영수증(또는 주문번호/구매일) 사진
# - 파손 사진(전면 전체, 근접 각 1–2장)
# - 연락처(휴대폰 번호) 및 수리 받을 주소
#
# 3) 접수 방법(선택)
# - 온라인 접수(사진·서류 업로드) → 택배 픽업 또는 발송 안내
# - 전화/채팅 접수 → 센터 예약 또는 택배 수거 신청
# - 방문 접수 → 공인 서비스센터 예약 후 방문
#
# 4) 진단·보증 적용·비용 처리
# - 도착 후 기술 진단(1–3 영업일) → 보증 적용 여부 통보
# - 제조 결함이면 무상 수리(보증 적용)
# - 낙하·충격 등 ‘우발적 물리 손상’이면 보증 제외가 일반적이며 유상 수리(사전 견적 후 고객 승인)
# - 고객 동의 없이 비용 청구 없음
#
# 5) 소요 시간
# - 일반적 수리 기간: 접수부터 반송까지 약 5–10 영업일(부품 수급에 따라 변동)
#
# 6) 제가 도와드릴 수 있는 것
# - 지금 바로 수리 접수 대행(택배 픽업 포함) 또는 가까운 서비스센터 예약을 도와드리겠습니다.
# - 원격으로 간단 점검(터치 반응·화면 깜빡임 등) 안내도 가능
#
# 진행을 원하시면 아래 중 선택해 주세요:
# A) 지금 접수 진행(제가 택배 픽업/온라인 접수 대행) — 필요한 정보: 모델명, IMEI/S/N, 구매 영수증 사진, 파손 사진, 연락처, 수리 주소
# B) 서비스센터 방문 예약(원하시는 지역/일시 알려주세요)
# C) 우선 원격 점검 안내
#
# 어떤 방식으로 진행할까요?
# ================================= Tool Message =================================
# Name: provide_solution
#
# Solution provided: 간단히 정리해 드리겠습니다 — 지금 바로 하실 일과 수리 절차
#
# 1) 즉시 조치(안전 및 데이터 보호)
# - 전원 끄기: 유리 파편으로 인한 상해/추가 손상 방지.
# - 데이터 백업: iCloud/Google/PC 등으로 즉시 백업(수리 중 데이터 손실 가능).
# - SIM 카드·외장메모리 제거, 케이스·필름 제거.
# - 파손 부위로 다칠 위험이 있으면 보호장갑 착용, 임시로 투명테이프로 고정.
#
# 2) 수리 접수 준비물
# - 모델명, IMEI 또는 S/N
# - 구매 영수증(또는 주문번호/구매일) 사진
# - 파손 사진(전면 전체, 근접 각 1–2장)
# - 연락처(휴대폰 번호) 및 수리 받을 주소
#
# 3) 접수 방법(선택)
# - 온라인 접수(사진·서류 업로드) → 택배 픽업 또는 발송 안내
# - 전화/채팅 접수 → 센터 예약 또는 택배 수거 신청
# - 방문 접수 → 공인 서비스센터 예약 후 방문
#
# 4) 진단·보증 적용·비용 처리
# - 도착 후 기술 진단(1–3 영업일) → 보증 적용 여부 통보
# - 제조 결함이면 무상 수리(보증 적용)
# - 낙하·충격 등 ‘우발적 물리 손상’이면 보증 제외가 일반적이며 유상 수리(사전 견적 후 고객 승인)
# - 고객 동의 없이 비용 청구 없음
#
# 5) 소요 시간
# - 일반적 수리 기간: 접수부터 반송까지 약 5–10 영업일(부품 수급에 따라 변동)
#
# 6) 제가 도와드릴 수 있는 것
# - 지금 바로 수리 접수 대행(택배 픽업 포함) 또는 가까운 서비스센터 예약을 도와드리겠습니다.
# - 원격으로 간단 점검(터치 반응·화면 깜빡임 등) 안내도 가능
#
# 진행을 원하시면 아래 중 선택해 주세요:
# A) 지금 접수 진행(제가 택배 픽업/온라인 접수 대행) — 필요한 정보: 모델명, IMEI/S/N, 구매 영수증 사진, 파손 사진, 연락처, 수리 주소
# B) 서비스센터 방문 예약(원하시는 지역/일시 알려주세요)
# C) 우선 원격 점검 안내
#
# 어떤 방식으로 진행할까요?
# ================================== Ai Message ==================================
# Tool Calls:
#   provide_solution (call_4TFD6tqqkt5DjcLyh9ATiKjv)
#  Call ID: call_4TFD6tqqkt5DjcLyh9ATiKjv
#   Args:
#     solution: 지금 바로 진행해 드리겠습니다 — 간단한 요약과 선택지
#
# 요약
# - 보증 기간 내이므로 우선 보증 수리로 접수해 기술 진단을 진행하겠습니다. 다만 낙하로 인한 화면 파손은 ‘우발적 물리 손상’으로 보증 제외될 가능성이 높아, 최종 판단은 현장 진단 이후 확정됩니다. 보증 미적용 시 유상 견적을 안내해 드리며, 고객 승인 후 수리합니다. 고객 동의 없이 비용 청구는 없습니다.
#
# 지금 즉시 해야 할 일(안전 및 데이터 보호)
# 1. 전원 끄기
# 2. 중요 데이터 백업(iCloud/Google/PC)
# 3. SIM·외장메모리·케이스 제거
# 4. 깨진 유리로 다칠 위험 시 보호장갑 착용 및 투명테이프로 임시 고정
#
# 수리 접수에 필요한 정보(접수 전 준비)
# - 모델명, IMEI 또는 S/N
# - 구매 영수증(또는 주문번호/구매일) 사진
# - 파손 사진(전면 전체, 근접 각 1–2장)
# - 연락처(휴대폰 번호) 및 수리 받을 주소
#
# 진행 방법(선택) — 원하시는 항목을 알려 주세요
# A) 제가 온라인 접수·택배 픽업 대행(권장)
#    • 필요한 정보: 모델명, IMEI/SN, 영수증 사진, 파손 사진, 연락처, 수리 주소
# B) 가까운 공인 서비스센터 방문 예약(원하시는 지역/가능 일시 알려 주세요)
# C) 우선 원격 점검(터치 반응·화면 깜빡임 등 간단 점검 안내)
#
# 소요 시간 및 비용 안내
# - 진단: 도착 후 1–3 영업일, 전체 수리(부품수급 포함): 보통 5–10 영업일
# - 보증 적용 시 무상, 우발적 손상 판정 시 유상(사전 견적·승인)
#
# 어떻게 진행할까요? 선택(A/B/C)과 함께 A를 선택하시면 접수에 필요한 정보를 바로 보내 주세요.
# ================================= Tool Message =================================
# Name: provide_solution
#
# Solution provided: 지금 바로 진행해 드리겠습니다 — 간단한 요약과 선택지
#
# 요약
# - 보증 기간 내이므로 우선 보증 수리로 접수해 기술 진단을 진행하겠습니다. 다만 낙하로 인한 화면 파손은 ‘우발적 물리 손상’으로 보증 제외될 가능성이 높아, 최종 판단은 현장 진단 이후 확정됩니다. 보증 미적용 시 유상 견적을 안내해 드리며, 고객 승인 후 수리합니다. 고객 동의 없이 비용 청구는 없습니다.
#
# 지금 즉시 해야 할 일(안전 및 데이터 보호)
# 1. 전원 끄기
# 2. 중요 데이터 백업(iCloud/Google/PC)
# 3. SIM·외장메모리·케이스 제거
# 4. 깨진 유리로 다칠 위험 시 보호장갑 착용 및 투명테이프로 임시 고정
#
# 수리 접수에 필요한 정보(접수 전 준비)
# - 모델명, IMEI 또는 S/N
# - 구매 영수증(또는 주문번호/구매일) 사진
# - 파손 사진(전면 전체, 근접 각 1–2장)
# - 연락처(휴대폰 번호) 및 수리 받을 주소
#
# 진행 방법(선택) — 원하시는 항목을 알려 주세요
# A) 제가 온라인 접수·택배 픽업 대행(권장)
#    • 필요한 정보: 모델명, IMEI/SN, 영수증 사진, 파손 사진, 연락처, 수리 주소
# B) 가까운 공인 서비스센터 방문 예약(원하시는 지역/가능 일시 알려 주세요)
# C) 우선 원격 점검(터치 반응·화면 깜빡임 등 간단 점검 안내)
#
# 소요 시간 및 비용 안내
# - 진단: 도착 후 1–3 영업일, 전체 수리(부품수급 포함): 보통 5–10 영업일
# - 보증 적용 시 무상, 우발적 손상 판정 시 유상(사전 견적·승인)
#
# 어떻게 진행할까요? 선택(A/B/C)과 함께 A를 선택하시면 접수에 필요한 정보를 바로 보내 주세요.
# ================================== Ai Message ==================================
# Tool Calls:
#   provide_solution (call_xiiKoLhEgPUplgTFEdo5vQvu)
#  Call ID: call_xiiKoLhEgPUplgTFEdo5vQvu
#   Args:
#     solution: 간단 명료하게 안내드립니다 — 지금 바로 하실 일과 수리 진행 방식(권장 순서)
#
# 즉시 해야 할 일(안전·데이터 보호)
# 1. 기기 전원 끄기(유리 파편·추가 손상 방지).
# 2. 중요한 데이터 즉시 백업(iCloud/Google/PC 등).
# 3. SIM·외장메모리·케이스·화면필름 제거.
# 4. 깨진 유리로 다칠 위험이 있으면 보호장갑 착용, 파손부를 투명테이프로 임시 고정.
#
# 수리 진행(권장: 온라인 접수 + 택배 픽업)
# - 이유: 집에서 간편하게 택배 픽업으로 보내실 수 있어 이동 불편 최소화, 서류·사진 업로드로 접수 빠름.
# - 절차: 사진·영수증 업로드 → 택배 픽업 일정 조율 → 수리 센터 진단(1–3 영업일) → 보증 적용 여부 통보 → 유상 시 견적 확인 후 고객 승인 → 수리 후 발송
# - 소요 기간: 보통 5–10 영업일(부품 수급·센터 상황에 따라 변동)
#
# 필요한 자료(지금 바로 준비해 주세요)
# - 모델명, IMEI 또는 S/N
# - 구매 영수증(또는 주문번호·구매일) 사진
# - 파손 사진(전면 전체, 파손부 근접 각 1–2장)
# - 연락처(휴대전화) 및 수리 받을 주소
#
# 비용 관련 안내
# - 보증 기간 내 접수하더라도 낙하·충격은 ‘우발적 손상’으로 보증 제외될 가능성이 큽니다. 진단 후 보증 적용 여부 확정, 유상일 경우 사전 견적 안내 및 고객 승인 후 진행
#
# 제가 바로 도와드릴 수 있는 것
# A) 지금 온라인 접수·택배 픽업 대행(권장) — 진행 원하시면 위 자료를 보내 주세요.
# B) 가까운 공인 서비스센터 방문 예약 — 원하시는 지역/가능 일시 알려 주세요.
# C) 우선 원격 점검(터치 반응·화면 깜빡임 등) 안내—원하시면 바로 시작하겠습니다.
#
# 어떤 방식으로 진행할지(A/B/C)을 알려 주세요. 바로 접수 진행을 원하시면 위 자료를 보내 주시면 제가 접수를 시작하겠습니다.
# ================================= Tool Message =================================
# Name: provide_solution
#
# Solution provided: 간단 명료하게 안내드립니다 — 지금 바로 하실 일과 수리 진행 방식(권장 순서)
#
# 즉시 해야 할 일(안전·데이터 보호)
# 1. 기기 전원 끄기(유리 파편·추가 손상 방지).
# 2. 중요한 데이터 즉시 백업(iCloud/Google/PC 등).
# 3. SIM·외장메모리·케이스·화면필름 제거.
# 4. 깨진 유리로 다칠 위험이 있으면 보호장갑 착용, 파손부를 투명테이프로 임시 고정.
#
# 수리 진행(권장: 온라인 접수 + 택배 픽업)
# - 이유: 집에서 간편하게 택배 픽업으로 보내실 수 있어 이동 불편 최소화, 서류·사진 업로드로 접수 빠름.
# - 절차: 사진·영수증 업로드 → 택배 픽업 일정 조율 → 수리 센터 진단(1–3 영업일) → 보증 적용 여부 통보 → 유상 시 견적 확인 후 고객 승인 → 수리 후 발송
# - 소요 기간: 보통 5–10 영업일(부품 수급·센터 상황에 따라 변동)
#
# 필요한 자료(지금 바로 준비해 주세요)
# - 모델명, IMEI 또는 S/N
# - 구매 영수증(또는 주문번호·구매일) 사진
# - 파손 사진(전면 전체, 파손부 근접 각 1–2장)
# - 연락처(휴대전화) 및 수리 받을 주소
#
# 비용 관련 안내
# - 보증 기간 내 접수하더라도 낙하·충격은 ‘우발적 손상’으로 보증 제외될 가능성이 큽니다. 진단 후 보증 적용 여부 확정, 유상일 경우 사전 견적 안내 및 고객 승인 후 진행
#
# 제가 바로 도와드릴 수 있는 것
# A) 지금 온라인 접수·택배 픽업 대행(권장) — 진행 원하시면 위 자료를 보내 주세요.
# B) 가까운 공인 서비스센터 방문 예약 — 원하시는 지역/가능 일시 알려 주세요.
# C) 우선 원격 점검(터치 반응·화면 깜빡임 등) 안내—원하시면 바로 시작하겠습니다.
#
# 어떤 방식으로 진행할지(A/B/C)을 알려 주세요. 바로 접수 진행을 원하시면 위 자료를 보내 주시면 제가 접수를 시작하겠습니다.
# ================================== Ai Message ==================================
#
# 도움이 필요하시면 진행 방식(A/B/C) 중 하나 선택해주세요. 제가 바로 도와드리겠습니다.
#
# 현재 단계: resolution_specialist

# %% [markdown]
# ## 8. 상태 전환 시각화
#
# 각 턴에서 상태가 어떻게 변경되는지 확인합니다.

# %%
# 전체 대화 흐름 요약
print("=" * 80)
print("워크플로우 상태 전환 요약:")
print("=" * 80)
print("\n턴 1: warranty_collector (보증 확인)")
print("  → 고객에게 보증 상태 질문")
print("\n턴 2: warranty_collector → issue_classifier")
print("  → 보증 상태 기록, 이슈 분류 단계로 전환")
print("\n턴 3: issue_classifier → resolution_specialist")
print("  → 이슈 유형 기록, 해결책 제공 단계로 전환")
print("\n턴 4: resolution_specialist")
print("  → 최종 해결책 제공")
# Out:
# ================================================================================
# 워크플로우 상태 전환 요약:
# ================================================================================
#
# 턴 1: warranty_collector (보증 확인)
#   → 고객에게 보증 상태 질문
#
# 턴 2: warranty_collector → issue_classifier
#   → 보증 상태 기록, 이슈 분류 단계로 전환
#
# 턴 3: issue_classifier → resolution_specialist
#   → 이슈 유형 기록, 해결책 제공 단계로 전환
#
# 턴 4: resolution_specialist
#   → 최종 해결책 제공

# %% [markdown]
# ## 9. 보증 기간 만료 시나리오
#
# 보증 기간이 만료된 경우의 워크플로우를 테스트합니다.

# %%
# 새로운 스레드로 보증 기간 만료 시나리오
thread_id2 = str(uuid.uuid4())
config2 = {"configurable": {"thread_id": thread_id2}}

print("=" * 80)
print("보증 기간 만료 시나리오:")
print("=" * 80)

# 턴 1
result = agent.invoke(
    {"messages": [HumanMessage(content="제품에 문제가 있어요.")]},
    config=config2
)

# 턴 2: 보증 기간 만료
result = agent.invoke(
    {"messages": [HumanMessage(content="아니요, 보증 기간이 지났어요.")]},
    config=config2
)

print(f"보증 상태: {result.get('warranty_status', 'N/A')}")

# 턴 3: 하드웨어 문제
result = agent.invoke(
    {"messages": [HumanMessage(content="하드웨어 문제예요. 배터리가 부풀어 올랐어요.")]},
    config=config2
)

print(f"이슈 유형: {result.get('issue_type', 'N/A')}")

# 턴 4: 해결책 (에스컬레이션 예상)
result = agent.invoke(
    {"messages": [HumanMessage(content="어떻게 해야 하나요?")]},
    config=config2
)

for msg in result["messages"]:
    if hasattr(msg, 'pretty_print'):
        msg.pretty_print()
    else:
        print(msg)
# Out:
# ================================================================================
# 보증 기간 만료 시나리오:
# ================================================================================
# 보증 상태: out_of_warranty
# 이슈 유형: hardware
# ================================ Human Message =================================
#
# 제품에 문제가 있어요.
# ================================== Ai Message ==================================
#
# 안녕하세요! 도와드리겠습니다. 사용 중인 제품이 아직 보증 기간 내에 있나요? (예 / 아니오로 답해 주세요.)
# ================================ Human Message =================================
#
# 아니요, 보증 기간이 지났어요.
# ================================== Ai Message ==================================
# Tool Calls:
#   record_warranty_status (call_k5d2gpPDahBhQLaEHqupSbGo)
#  Call ID: call_k5d2gpPDahBhQLaEHqupSbGo
#   Args:
#     status: out_of_warranty
# ================================= Tool Message =================================
# Name: record_warranty_status
#
# Warranty status recorded as: out_of_warranty
# ================================== Ai Message ==================================
#
# 알겠습니다 — 도와드리겠습니다. 몇 가지 확인해서 문제 유형(하드웨어 vs 소프트웨어)을 분류해야 합니다. 번거로우시겠지만 아래 항목들에 답해 주세요:
#
# 1. 문제가 정확히 무엇인가요? (증상 상세 설명)
#    - 예: 전원이 켜지지 않음, 화면 깜빡임/터치 불가, 소음/발열, 배터리 빨리 닳음, 앱 충돌/응답 없음, 업데이트 후 문제 등
#
# 2. 문제가 언제부터 발생했나요? 갑자기 시작했나요, 아니면 서서히 악화됐나요?
#
# 3. 최근에 기기를 떨어뜨리거나 물이 닿는 등 물리적 충격이나 액체 노출이 있었나요? 외관상 손상(금/금이 간 화면, 부품 탈락 등)이 보이나요?
#
# 4. 오류 메시지나 코드가 보이면 정확한 문구를 알려 주세요(스크린샷 가능하면 첨부).
#
# 5. 이미 시도해 본 해결 방법이 있나요? (예: 재부팅, 공장초기화, 앱 삭제/재설치, 업데이트 등)
#
# 6. 기기 모델명(또는 제품명)과 사용 중인 운영체제/앱 버전도 알려 주세요.
#
# 이 정보로 문제를 하드웨어인지 소프트웨어인지 판단한 뒤, 분류를 기록하고 다음 단계로 진행하겠습니다.
# ================================ Human Message =================================
#
# 하드웨어 문제예요. 배터리가 부풀어 올랐어요.
# ================================== Ai Message ==================================
# Tool Calls:
#   record_issue_type (call_W0iFl75dVl1AKZKEMMEuZcRJ)
#  Call ID: call_W0iFl75dVl1AKZKEMMEuZcRJ
#   Args:
#     issue_type: hardware
# ================================= Tool Message =================================
# Name: record_issue_type
#
# Issue type recorded as: hardware
# ================================== Ai Message ==================================
# Tool Calls:
#   escalate_to_human (call_0csSLIHgISIJlxYeb14Y4Ji2)
#  Call ID: call_0csSLIHgISIJlxYeb14Y4Ji2
#   Args:
#     reason: Out-of-warranty hardware issue: swollen battery. Customer reports battery swelling (potential safety hazard). Warranty status: out_of_warranty. Request escalation to human support for paid repair options, disposal/recycling instructions, authorized service center locations, cost estimate, and next steps for safe transport/drop-off or on-site pickup.
# ================================= Tool Message =================================
# Name: escalate_to_human
#
# Escalating to human support. Reason: Out-of-warranty hardware issue: swollen battery. Customer reports battery swelling (potential safety hazard). Warranty status: out_of_warranty. Request escalation to human support for paid repair options, disposal/recycling instructions, authorized service center locations, cost estimate, and next steps for safe transport/drop-off or on-site pickup.
# ================================== Ai Message ==================================
#
# 중요: 배터리 부풀음은 안전 위험(발화·폭발·유해가스) 가능성이 있으므로 즉시 주의가 필요합니다. 보증 만료 상태이므로 유료 수리를 위한 인간 지원팀으로 에스컬레이션하였고, 지원팀에서 연락드려 다음 정보를 안내해 드릴 것입니다.
#
# 즉시 권장 조치(안전 지침):
# - 전원 연결 해제: 즉시 충전기나 전원에서 분리하세요.
# - 사용 중지: 기기를 더 이상 사용하거나 전원 켜지지 않게 하지 마세요.
# - 통풍이 잘되는 안전한 장소에 보관: 직사광선과 고온 장소를 피하세요.
# - 물리적 조작 금지: 펀치, 압박, 바늘 등으로 배터리를 찌르거나 구멍 내지 마세요.
# - 이동 시 주의: 이동이 꼭 필요한 경우 안정된 평평한 용기에 넣어 흔들림을 최소화하세요.
# - 화재 대비: 집에 소화기(분말형 권장)가 있으면 가까운 곳에 두세요.
#
# 지원팀에서 받을 안내(예상):
# - 유료 수리/교체 견적 및 결제 방법
# - 공인 서비스 센터 위치 또는 방문 수리 예약
# - 안전한 폐배터리 처리 및 리싸이클 절차
# - 수거/반납 시 주의사항(포장 방법, 착불 여부 등)
# - 수리 소요 시간 예상
#
# 지금 추가로 알려주시면 더 빠르게 도움드리겠습니다:
# 1) 기기 모델명과 시리얼(또는 구입 연도)
# 2) 현재 위치(도시/우편번호) — 가까운 서비스 센터 안내를 위해
# 3) 기기를 바로 가져갈 수 있는지, 혹은 방문 수거를 원하시는지
#
# 추가 정보 주시면 에스컬레이션 티켓에 포함해 담당자가 연락드리도록 하겠습니다. 안전이 최우선이니 우선 위 안전 지침을 따라 주세요.
# ================================ Human Message =================================
#
# 어떻게 해야 하나요?
# ================================== Ai Message ==================================
#
# 안전이 최우선입니다. 먼저 지금 바로 할 수 있는 행동과 이후 절차를 간단히 정리해 드립니다.
#
# 즉시 해야 할 일
# - 충전기·전원 분리: 즉시 충전기에서 분리하고 전원 연결을 절대 하지 마세요.
# - 사용 중지: 전원 켜기, 터치·눌러 보기 같은 시도 금지(전기·압력으로 악화될 수 있음).
# - 통풍이 잘되는 안전한 장소에 보관: 직사광선·열원·가연물(커튼, 종이 등)에서 멀리 둡니다.
# - 물리적 손대지 마세요: 배터리 찌르기·구멍내기·압박·펀치 등 절대 금지.
# - 화재 위험 대비: 주변에 소화기(분말형 권장)가 있으면 준비, 연기·열·발화 시 즉시 대피 후 119(한국) 등 긴급 연락.
#
# 보관·이동 시 주의사항
# - 가능하면 단단한 평평한 비가연성(금속·세라믹 등) 표면에 올려 두세요.
# - 이동이 꼭 필요하면 흔들림이 적은 단단한 용기(박스 등)에 넣어 고정하고 통풍이 있는 상태로 옮기세요.
# - 봉인된 밀폐용기(예: 완전 밀폐된 플라스틱 백)는 가스 발생 시 위험할 수 있으니 피하세요.
# - 스스로 배터리를 분리·교체하려 하지 마세요(위험).
#
# 다음에 저희가 해드릴 것(이미 지원팀에 에스컬레이션 진행)
# - 유료 수리(배터리 교체) 견적, 결제 방법, 공인 서비스센터 위치 또는 방문 수거 예약 등 담당자가 연락드려 안내해 드립니다.
# - 폐배터리 안전 처리 및 재활용 안내(일반 쓰레기 투기는 금지)도 안내해 드립니다.
#
# 고객님께 드릴 요청(빠른 처리 위해 알려주세요)
# 1) 기기 모델명과 시리얼(또는 사진)
# 2) 현재 위치(도시/우편번호) — 가까운 서비스센터 안내 및 방문수거 여부 확인용
# 3) 직접 방문 가능한지, 아니면 수거를 원하시는지
# 4) 기기 외관 사진(배터리 부풀음 상태가 보이는 사진) — 티켓에 첨부하면 처리 속도 빨라집니다
#
# 긴급 상황(열·연기·발화 발생 시)
# - 즉시 안전한 거리로 대피하고 119에 신고하세요. 인명 우선입니다.
#
# 지금 모델명과 위치 알려주시면 에스컬레이션 티켓에 추가해 담당자가 가능한 빠르게 연락드리도록 하겠습니다. 안전 지침을 우선 따라 주세요.

# %% [markdown]
# ## 주요 포인트 정리
#
# 1. **단일 에이전트, 다중 상태**: 하나의 에이전트가 여러 상태를 거침
# 2. **상태 기반 라우팅**: 현재 상태에 따라 다른 프롬프트와 도구 사용
# 3. **상태 전환**: 도구 호출을 통해 상태 업데이트 및 전환
# 4. **체크포인터**: 대화 이력과 상태를 유지
# 5. **wrap_model_call + request.override**: 상태에 따라 프롬프트와 도구를 단계별로 주입
#
# **다음 단계**:
# - [330_Router_Pattern.py](330_Router_Pattern.py)에서 라우터 패턴 학습
# - [340_Skills_Pattern.py](340_Skills_Pattern.py)에서 스킬 기반 패턴 학습
